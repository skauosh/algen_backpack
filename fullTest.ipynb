# %%
import numpy as np
import random

MAX_PAIRING_ATTEMPTS = 100
MUTATION_BITFLIP_CHANCE = 1/32

def terminationCondition():
    return True

#simpler block for testing
class Block2:
    def __init__(self, dim):
        self.type = 0
        self.rot = np.zeros((dim - 1,), dtype=int) 
        self.X = np.zeros((dim,), dtype=int)

class Algorithm:
    def __init__(self, dimensionality, typeValueArray):
        self.blockSetup = []
        self.typeValueArray = typeValueArray
        self.BlockPhenotype = [] # array of arrays of phenotypes in !!BINARY!!
        self.Dimensionality = dimensionality
        #rotation: 2 bits per dimension - 1 (since we do 0: 00 degrees, 01 = 90, 10 = 180, 11 = 270)
        #1 bit for if inside backpack or not
        #don't remember max backpack size, will assume it to be char, so 8 bits per coordinate
        self.rotationStride = 0 
        self.coordinatesStride =  (dimensionality - 1)*2 

        #collection that stores phenotypes (backpacks)
        #backpacks are an array of (blockBinary, type)
        self.Phenotypes = []
        self.PreviousGen = []
        self.BestSpecimenID = 0

    #creates a backpack from [] of blocks, ONLY CALL AT CREATION NOT AFTER ITERATING
    def CreateAndAddPhenotype(self, blocks):
        backpack = []
        for b in blocks:
            backpack.append((self.__translateBlockToBinary(b), b.type))

        self.Phenotypes.append(backpack)

    def ListCurrentPhenotypes(self):
        for a in self.Phenotypes:
            print('Backpack:', end="")
            for b in a:
                c =  self.__translateBinaryToBlock(b[0])
                print(f' X:{c.X[0]} Y:{c.X[1]} R:{c.rot[0]} | ', end="")
            print('\n', end="")

    #biasParameter decides how "wide" the interval around quality of one specimen from which partner is accepted is
    def PairParentsUp(self, biasParameter, incestSwitch = 0):
        parentPairs = [] #format parentPairs[par1] = par2, int array
        
        highestSpecimenQuality = 0
        self.BestSpecimenID = 0
        sum = 0
        for backpack in self.Phenotypes:
            a = self.QualityFunction(backpack)
            sum += a
            if a > highestSpecimenQuality:
                self.BestSpecimenID = self.Phenotypes.index(backpack)
                highestSpecimenQuality = a

        avgQuality = sum/len(self.Phenotypes)
        print(f'Average pop quality: {avgQuality}')

        print(f'HIGHEST QUALITY IN GENERATION: {highestSpecimenQuality}')

        parentsIds = []
        for i in range(0, len(self.Phenotypes)):
            par1Id = random.randint(0, len(self.Phenotypes)-1)
            par2Id = random.randint(0, len(self.Phenotypes)-1)
            
            par1Quality = self.QualityFunction(self.Phenotypes[par1Id])
            par2Quality = self.QualityFunction(self.Phenotypes[par2Id])

            if(par1Quality >= par2Quality):
                parentsIds.append(par1Id)
            else:
                parentsIds.append(par2Id)

        for parentId in parentsIds:
            specimenQuality = self.QualityFunction(self.Phenotypes[parentId])
            lowerRange = specimenQuality - specimenQuality*biasParameter
            higherRange = specimenQuality + specimenQuality*biasParameter

            while True:
                potentialMateId = random.randint(0, len(self.Phenotypes)-1)
                qualityOfPotMate = self.QualityFunction(self.Phenotypes[potentialMateId])

                if((qualityOfPotMate > lowerRange) and (qualityOfPotMate < higherRange) and potentialMateId != self.Phenotypes.index(backpack)):
                    parentPairs.append((parentId, potentialMateId))
                    break
                elif(i > MAX_PAIRING_ATTEMPTS):
                    parentPairs.append((parentId, potentialMateId)) #if paring fails, just adds random
                    break
                i=i+1


        return parentPairs


    #checks how much value we store inside a backpack
    #takes negative values based on how much "illegal" the configuration is
    def QualityFunction(self, backpack): #typeValueArray is array that stores costs for given types
        quality = 0
        #here we need to check legality of a backpack
        for blockTuple in backpack:
            if(self.isInsideBackpack(blockTuple)):
                quality += self.typeValueArray[blockTuple[1]] 
            #generally, the alogorith will decide if the block is inside by moving coordinates
            #so no need for special bit for "isInsideBackpack"
        return quality

    #no sensical implementation for testing sake, HARDCODED FOR 2 DIM
    def isInsideBackpack(self, blockTuple):
        block = self.__translateBinaryToBlock(blockTuple[0])

        type = blockTuple[1]

        if(block.X[0] < 10 and block.X[0] > -10 and block.X[1] < 10 and block.X[1] > -10):
            return True
        else:
            return False

    #parentPairs - array[idOfParent1] = idOfParent2
    def OnePointCrossoverRecombination(self, parentPairs, probability):
        #probability = chance for each parent pair to create an offspring by crossover 
        #1 - probabilty = children will be copies of one of the parents
        #returns phenotypes
        newGen = []
        for pair in parentPairs:
            rng = random.random()
            if (rng > probability):
                #crossover - we randomly copy one of the parents
                whichParent = random.random()
                if (whichParent > 0.5):
                    newOne = self.BitFlipMutation(self.Phenotypes[pair[0]], MUTATION_BITFLIP_CHANCE)
                    newGen.append(newOne)
                else:
                    newOne = self.BitFlipMutation(self.Phenotypes[pair[1]], MUTATION_BITFLIP_CHANCE)
                    newGen.append(newOne)
            else: 
                #recombination - we take two parents, split them in a random point.
                combined = []
                length = min(len(self.Phenotypes[pair[0]]), len(self.Phenotypes[pair[1]]))

                splitPoint = random.randint(0, length)

                for j in range(0, splitPoint):
                    combined.append(self.Phenotypes[pair[0]][j])
                for j in range(splitPoint, length):
                    combined.append(self.Phenotypes[pair[1]][j])

                combined = self.BitFlipMutation(combined, MUTATION_BITFLIP_CHANCE)
                newGen.append(combined)
        return newGen

    #flips bits of a phenotype, probability shouldn't be too big
    def BitFlipMutation(self, phenotype, probability): 
        new_phenotype = []
        for i in range(0, len(phenotype)): #over blocks
            newBin = 0b0
            for j in range(int(phenotype[i][0]).bit_length()): #over bits of a block int(my_np_int64)
                bit = (phenotype[i][0] >> j) & 1
                rng = random.random()
                if (rng < probability):
                    bit ^= 1
                newBin |= (bit << j)
            if random.random() < probability: #since above mutation makes binary numbers smaller with many iterations, some chance to grow them
                newBin |= (1 << int(phenotype[i][0]).bit_length())
            new_phenotype.append((newBin, phenotype[i][1]))
        return new_phenotype


    #takes initial block setup, then randomizes and adds to current population, based on its size
    def Imigration(self, percent):
        immigrants = self.blockSetup
        random.shuffle(immigrants)

        for i in range(0, int(percent*len(self.Phenotypes))):
            for b in immigrants:
                b.X[0] = random.randint(-400, 400) #set x
                b.X[1] = random.randint(-400, 400) #set y
                b.rot[0] = random.randint(0, 1) #doesn't do anything yet so whatever
            self.CreateAndAddPhenotype(immigrants) 


    def Iterate(self):
        self.PreviousGen = self.Phenotypes
        #self.Imigration(0.1)
        parentPair = self.PairParentsUp(0.20)

        print('Backpack:', end="")
        for b in self.Phenotypes[self.BestSpecimenID]:
            c =  self.__translateBinaryToBlock(b[0])
            print(f' X:{c.X[0]} Y:{c.X[1]} R:{c.rot[0]} T:{b[1]} | ', end="")
        print('\n', end="")
        
        self.Phenotypes = self.OnePointCrossoverRecombination(parentPair, 0.75)


    def __translateBlockToBinary(self, block):
        binaryBlock = np.int64(0) #force 64 bit ints, max dimensionality is limited by this

        for i in range(self.Dimensionality-1): #set single rotation bits
            binaryBlock |= (block.rot[i] << 2*i) #i assume rotation is array,

        for i in range(self.Dimensionality):
            binaryBlock |= block.X[i] << (self.coordinatesStride + (i*8))

        return binaryBlock

    def __translateBinaryToBlock(self, blockInt64):
        block = Block2(self.Dimensionality)
        block.X = np.zeros(self.Dimensionality, dtype=np.int8)
        block.rot = np.zeros(self.Dimensionality-1, dtype=int)
        block.isInside = 0

        for i in range(self.Dimensionality - 1, -1, -1): #set single rotation bits
           block.X[i] = (blockInt64 >> self.coordinatesStride + (i*8) ) & 0xFF # &0xFF masks out bits leftover to the left

        for i in range(self.Dimensionality - 2, -1, -1): #set single rotation bits
           block.rot[i] = (blockInt64 >> (i*2)) & 0b11

        return block

# %%
typeValueArray = [10, 15, 20, 25, 1, 23] #3 type of blocks, 0 - worth 10 etc.

blocksFor1stBackpack = []

Algo = Algorithm(2, typeValueArray)

for j in range(0, 30):
    b = Block2(2)
    b.type = random.randint(0, 4)
    blocksFor1stBackpack.append(b)

Algo.blockSetup = blocksFor1stBackpack.copy()

highestAchivableQuality = 0
for b in blocksFor1stBackpack:
    highestAchivableQuality += typeValueArray[b.type]
    
print(f'HIGHEST ACHIVABLE QUALITY: {highestAchivableQuality}')

#randomize X and Y from all of initial 300 blocks
for i in range(0, 2000):
    for b in blocksFor1stBackpack:
        b.X[0] = random.randint(-400, 400) #set x
        b.X[1] = random.randint(-400, 400) #set y
        b.rot[0] = random.randint(0, 1) #doesn't do anything yet so whatever
    Algo.CreateAndAddPhenotype(blocksFor1stBackpack) 


for i in range(1, 100):
    Algo.Iterate()
    print(f'-------------------------------- {i+1} GEN ---------------------------------------')

Algo.ListCurrentPhenotypes()
# Out:
# HIGHEST ACHIVABLE QUALITY: 497
# Average pop quality: 18.8945
# HIGHEST QUALITY IN GENERATION: 105
# Backpack: X:-29 Y:-98 R:1 T:0 |  X:26 Y:19 R:1 T:3 |  X:-1 Y:-1 R:0 T:2 |  X:122 Y:-2 R:0 T:3 |  X:-72 Y:-20 R:1 T:2 |  X:122 Y:-2 R:1 T:2 |  X:-11 Y:-77 R:1 T:2 |  X:12 Y:-1 R:0 T:1 |  X:-68 Y:-1 R:1 T:0 |  X:-51 Y:-1 R:0 T:3 |  X:-67 Y:-1 R:1 T:0 |  X:78 Y:-1 R:0 T:2 |  X:1 Y:-1 R:1 T:0 |  X:104 Y:-49 R:0 T:4 |  X:9 Y:105 R:0 T:0 |  X:-84 Y:-1 R:0 T:0 |  X:95 Y:79 R:0 T:2 |  X:-11 Y:-2 R:0 T:4 |  X:25 Y:-1 R:1 T:3 |  X:99 Y:12 R:1 T:1 |  X:123 Y:-26 R:0 T:3 |  X:40 Y:-1 R:1 T:2 |  X:0 Y:-1 R:1 T:2 |  X:-63 Y:-26 R:1 T:0 |  X:-2 Y:39 R:0 T:2 |  X:61 Y:-18 R:1 T:0 |  X:-3 Y:-1 R:0 T:3 |  X:-7 Y:-2 R:0 T:1 |  X:-47 Y:-1 R:1 T:3 |  X:-7 Y:-2 R:1 T:1 |
# -------------------------------- 2 GEN ---------------------------------------
# Average pop quality: 54.6965
# HIGHEST QUALITY IN GENERATION: 196
# Backpack: X:108 Y:0 R:0 T:0 |  X:1 Y:0 R:0 T:3 |  X:39 Y:0 R:1 T:2 |  X:85 Y:119 R:1 T:3 |  X:-102 Y:115 R:0 T:2 |  X:96 Y:0 R:0 T:2 |  X:33 Y:9 R:0 T:2 |  X:0 Y:0 R:1 T:1 |  X:-122 Y:109 R:1 T:0 |  X:1 Y:0 R:1 T:3 |  X:66 Y:13 R:0 T:0 |  X:81 Y:35 R:0 T:2 |  X:-119 Y:0 R:0 T:0 |  X:5 Y:0 R:0 T:4 |  X:-1 Y:105 R:1 T:0 |  X:78 Y:-47 R:1 T:0 |  X:80 Y:21 R:0 T:2 |  X:-27 Y:0 R:0 T:4 |  X:7 Y:0 R:1 T:3 |  X:-83 Y:0 R:0 T:1 |  X:3 Y:0 R:1 T:3 |  X:-9 Y:1 R:0 T:2 |  X:56 Y:28 R:1 T:2 |  X:56 Y:115 R:0 T:0 |  X:33 Y:0 R:1 T:2 |  X:-5 Y:0 R:1 T:0 |  X:4 Y:0 R:0 T:3 |  X:-90 Y:4 R:0 T:1 |  X:1 Y:0 R:1 T:3 |  X:69 Y:82 R:0 T:1 |
# -------------------------------- 3 GEN ---------------------------------------
# Average pop quality: 64.337
# HIGHEST QUALITY IN GENERATION: 195
# Backpack: X:-19 Y:0 R:0 T:0 |  X:1 Y:0 R:0 T:3 |  X:55 Y:0 R:1 T:2 |  X:84 Y:119 R:1 T:3 |  X:-118 Y:99 R:0 T:2 |  X:96 Y:0 R:1 T:2 |  X:33 Y:9 R:0 T:2 |  X:0 Y:0 R:1 T:1 |  X:-122 Y:109 R:1 T:0 |  X:1 Y:0 R:3 T:3 |  X:66 Y:29 R:0 T:0 |  X:81 Y:99 R:0 T:2 |  X:-119 Y:0 R:0 T:0 |  X:13 Y:0 R:0 T:4 |  X:-1 Y:105 R:1 T:0 |  X:78 Y:-47 R:1 T:0 |  X:-64 Y:21 R:0 T:2 |  X:-27 Y:0 R:0 T:4 |  X:5 Y:0 R:1 T:3 |  X:-83 Y:0 R:0 T:1 |  X:3 Y:0 R:1 T:3 |  X:-9 Y:1 R:0 T:2 |  X:56 Y:28 R:1 T:2 |  X:56 Y:115 R:0 T:0 |  X:41 Y:0 R:1 T:2 |  X:-5 Y:0 R:1 T:0 |  X:4 Y:0 R:0 T:3 |  X:-90 Y:4 R:0 T:1 |  X:1 Y:0 R:1 T:3 |  X:69 Y:90 R:0 T:1 |
# -------------------------------- 4 GEN ---------------------------------------
# Average pop quality: 73.6535
# HIGHEST QUALITY IN GENERATION: 210
# Backpack: X:20 Y:13 R:0 T:0 |  X:-32 Y:1 R:0 T:3 |  X:1 Y:0 R:0 T:2 |  X:4 Y:0 R:1 T:3 |  X:2 Y:0 R:0 T:2 |  X:106 Y:13 R:1 T:2 |  X:42 Y:0 R:1 T:2 |  X:14 Y:0 R:0 T:1 |  X:26 Y:0 R:0 T:0 |  X:53 Y:5 R:0 T:3 |  X:-90 Y:126 R:0 T:0 |  X:-8 Y:1 R:1 T:2 |  X:121 Y:88 R:1 T:0 |  X:45 Y:1 R:1 T:4 |  X:6 Y:0 R:1 T:0 |  X:-80 Y:-61 R:3 T:0 |  X:-123 Y:107 R:1 T:2 |  X:-29 Y:1 R:1 T:4 |  X:6 Y:0 R:0 T:3 |  X:51 Y:93 R:1 T:1 |  X:5 Y:0 R:1 T:3 |  X:2 Y:0 R:1 T:2 |  X:-18 Y:0 R:1 T:2 |  X:-21 Y:6 R:3 T:0 |  X:0 Y:0 R:1 T:2 |  X:70 Y:21 R:1 T:0 |  X:49 Y:0 R:0 T:3 |  X:42 Y:-82 R:0 T:1 |  X:4 Y:0 R:0 T:3 |  X:14 Y:0 R:1 T:1 |
# -------------------------------- 5 GEN ---------------------------------------
# Average pop quality: 83.206
# HIGHEST QUALITY IN GENERATION: 220
# Backpack: X:61 Y:0 R:1 T:0 |  X:9 Y:0 R:0 T:3 |  X:59 Y:0 R:0 T:2 |  X:6 Y:0 R:0 T:3 |  X:109 Y:98 R:0 T:2 |  X:117 Y:-124 R:0 T:2 |  X:-5 Y:0 R:1 T:2 |  X:-39 Y:0 R:0 T:1 |  X:36 Y:0 R:2 T:0 |  X:4 Y:0 R:3 T:3 |  X:5 Y:-29 R:1 T:0 |  X:8 Y:2 R:1 T:2 |  X:36 Y:0 R:1 T:0 |  X:60 Y:0 R:0 T:4 |  X:27 Y:0 R:1 T:0 |  X:-114 Y:0 R:1 T:0 |  X:70 Y:0 R:0 T:2 |  X:120 Y:89 R:2 T:4 |  X:4 Y:0 R:1 T:3 |  X:55 Y:65 R:0 T:1 |  X:58 Y:1 R:1 T:3 |  X:-18 Y:0 R:0 T:2 |  X:2 Y:0 R:0 T:2 |  X:1 Y:0 R:1 T:0 |  X:3 Y:0 R:0 T:2 |  X:7 Y:29 R:1 T:0 |  X:125 Y:113 R:0 T:3 |  X:-7 Y:0 R:0 T:1 |  X:-72 Y:50 R:0 T:3 |  X:0 Y:0 R:1 T:1 |
# -------------------------------- 6 GEN ---------------------------------------
# Average pop quality: 91.5895
# HIGHEST QUALITY IN GENERATION: 211
# Backpack: X:62 Y:0 R:1 T:0 |  X:8 Y:0 R:2 T:3 |  X:2 Y:0 R:0 T:2 |  X:4 Y:0 R:1 T:3 |  X:46 Y:0 R:0 T:2 |  X:-13 Y:112 R:0 T:2 |  X:8 Y:0 R:1 T:2 |  X:-65 Y:0 R:0 T:1 |  X:87 Y:8 R:1 T:0 |  X:9 Y:0 R:0 T:3 |  X:-10 Y:0 R:1 T:0 |  X:-33 Y:0 R:1 T:2 |  X:-99 Y:-126 R:0 T:0 |  X:-34 Y:0 R:1 T:4 |  X:8 Y:0 R:1 T:0 |  X:52 Y:0 R:1 T:0 |  X:39 Y:-39 R:0 T:2 |  X:8 Y:0 R:1 T:4 |  X:12 Y:0 R:0 T:3 |  X:7 Y:0 R:1 T:1 |  X:19 Y:0 R:1 T:3 |  X:100 Y:33 R:0 T:2 |  X:12 Y:0 R:2 T:2 |  X:3 Y:-69 R:0 T:0 |  X:0 Y:0 R:0 T:2 |  X:8 Y:0 R:0 T:0 |  X:3 Y:0 R:1 T:3 |  X:18 Y:0 R:0 T:1 |  X:26 Y:1 R:0 T:3 |  X:9 Y:0 R:2 T:1 |
# -------------------------------- 7 GEN ---------------------------------------
# Average pop quality: 100.9675
# HIGHEST QUALITY IN GENERATION: 230
# Backpack: X:6 Y:0 R:1 T:0 |  X:-12 Y:7 R:0 T:3 |  X:13 Y:0 R:1 T:2 |  X:3 Y:0 R:2 T:3 |  X:0 Y:0 R:1 T:2 |  X:55 Y:0 R:1 T:2 |  X:2 Y:0 R:3 T:2 |  X:32 Y:0 R:1 T:1 |  X:88 Y:-71 R:1 T:0 |  X:-2 Y:0 R:1 T:3 |  X:-126 Y:0 R:2 T:0 |  X:1 Y:0 R:0 T:2 |  X:7 Y:0 R:1 T:0 |  X:-107 Y:0 R:2 T:4 |  X:-97 Y:-29 R:3 T:0 |  X:-112 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:36 Y:0 R:0 T:4 |  X:119 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:1 |  X:13 Y:43 R:0 T:3 |  X:1 Y:0 R:0 T:2 |  X:4 Y:0 R:1 T:2 |  X:-57 Y:0 R:1 T:0 |  X:104 Y:0 R:1 T:2 |  X:-72 Y:109 R:0 T:0 |  X:31 Y:0 R:0 T:3 |  X:-84 Y:124 R:0 T:1 |  X:9 Y:0 R:2 T:3 |  X:-41 Y:-97 R:2 T:1 |
# -------------------------------- 8 GEN ---------------------------------------
# Average pop quality: 109.8185
# HIGHEST QUALITY IN GENERATION: 231
# Backpack: X:-81 Y:0 R:1 T:0 |  X:1 Y:0 R:0 T:3 |  X:117 Y:115 R:0 T:2 |  X:2 Y:0 R:0 T:3 |  X:-115 Y:2 R:3 T:2 |  X:-114 Y:-75 R:0 T:2 |  X:1 Y:0 R:0 T:2 |  X:-128 Y:-14 R:1 T:1 |  X:17 Y:0 R:2 T:0 |  X:8 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:0 |  X:9 Y:1 R:1 T:2 |  X:119 Y:0 R:1 T:0 |  X:-20 Y:0 R:3 T:4 |  X:-23 Y:25 R:3 T:0 |  X:20 Y:0 R:3 T:0 |  X:8 Y:0 R:1 T:2 |  X:2 Y:0 R:1 T:4 |  X:-5 Y:0 R:0 T:3 |  X:-3 Y:0 R:1 T:1 |  X:34 Y:1 R:0 T:3 |  X:-29 Y:-37 R:0 T:2 |  X:-75 Y:86 R:0 T:2 |  X:84 Y:0 R:1 T:0 |  X:7 Y:0 R:0 T:2 |  X:81 Y:0 R:0 T:0 |  X:2 Y:0 R:3 T:3 |  X:-123 Y:0 R:0 T:1 |  X:36 Y:0 R:1 T:3 |  X:-58 Y:0 R:2 T:1 |
# -------------------------------- 9 GEN ---------------------------------------
# Average pop quality: 118.9565
# HIGHEST QUALITY IN GENERATION: 270
# Backpack: X:0 Y:0 R:3 T:0 |  X:3 Y:0 R:1 T:3 |  X:1 Y:0 R:1 T:2 |  X:3 Y:6 R:0 T:3 |  X:0 Y:0 R:1 T:2 |  X:105 Y:100 R:0 T:2 |  X:84 Y:0 R:1 T:2 |  X:76 Y:-105 R:1 T:1 |  X:67 Y:0 R:1 T:0 |  X:-41 Y:48 R:0 T:3 |  X:44 Y:0 R:0 T:0 |  X:22 Y:0 R:0 T:2 |  X:4 Y:0 R:1 T:0 |  X:7 Y:-44 R:1 T:4 |  X:67 Y:0 R:0 T:0 |  X:-110 Y:0 R:1 T:0 |  X:55 Y:0 R:1 T:2 |  X:55 Y:0 R:1 T:4 |  X:6 Y:0 R:0 T:3 |  X:3 Y:0 R:0 T:1 |  X:0 Y:0 R:1 T:3 |  X:1 Y:0 R:0 T:2 |  X:0 Y:0 R:0 T:2 |  X:3 Y:0 R:0 T:0 |  X:-2 Y:0 R:0 T:2 |  X:-128 Y:-95 R:3 T:0 |  X:14 Y:0 R:0 T:3 |  X:124 Y:50 R:0 T:1 |  X:5 Y:3 R:1 T:3 |  X:-17 Y:-54 R:1 T:1 |
# -------------------------------- 10 GEN ---------------------------------------
# Average pop quality: 128.2585
# HIGHEST QUALITY IN GENERATION: 260
# Backpack: X:48 Y:0 R:1 T:0 |  X:1 Y:0 R:0 T:3 |  X:7 Y:0 R:3 T:2 |  X:6 Y:0 R:2 T:3 |  X:3 Y:0 R:1 T:2 |  X:76 Y:109 R:0 T:2 |  X:-81 Y:25 R:0 T:2 |  X:-2 Y:1 R:0 T:1 |  X:120 Y:0 R:3 T:0 |  X:3 Y:0 R:0 T:3 |  X:-12 Y:-86 R:0 T:0 |  X:-5 Y:0 R:3 T:2 |  X:121 Y:73 R:1 T:0 |  X:60 Y:-111 R:1 T:4 |  X:2 Y:0 R:1 T:0 |  X:-80 Y:-125 R:0 T:0 |  X:-125 Y:91 R:0 T:2 |  X:-61 Y:1 R:3 T:4 |  X:6 Y:0 R:0 T:3 |  X:5 Y:0 R:1 T:1 |  X:5 Y:0 R:1 T:3 |  X:-123 Y:-120 R:1 T:2 |  X:-66 Y:-45 R:2 T:2 |  X:-7 Y:3 R:1 T:0 |  X:21 Y:0 R:1 T:2 |  X:109 Y:99 R:0 T:0 |  X:-94 Y:111 R:0 T:3 |  X:18 Y:62 R:0 T:1 |  X:1 Y:0 R:0 T:3 |  X:119 Y:70 R:0 T:1 |
# -------------------------------- 11 GEN ---------------------------------------
# Average pop quality: 137.692
# HIGHEST QUALITY IN GENERATION: 260
# Backpack: X:53 Y:0 R:1 T:0 |  X:-2 Y:0 R:0 T:3 |  X:-3 Y:0 R:1 T:2 |  X:5 Y:0 R:1 T:3 |  X:0 Y:0 R:0 T:2 |  X:7 Y:0 R:1 T:2 |  X:114 Y:114 R:1 T:2 |  X:88 Y:82 R:3 T:1 |  X:111 Y:0 R:0 T:0 |  X:1 Y:0 R:0 T:3 |  X:-20 Y:0 R:1 T:0 |  X:58 Y:0 R:1 T:2 |  X:-66 Y:-62 R:3 T:0 |  X:108 Y:0 R:3 T:4 |  X:54 Y:23 R:3 T:0 |  X:26 Y:0 R:1 T:0 |  X:2 Y:0 R:1 T:2 |  X:-21 Y:73 R:0 T:4 |  X:-109 Y:0 R:0 T:3 |  X:1 Y:0 R:0 T:1 |  X:29 Y:1 R:0 T:3 |  X:6 Y:0 R:0 T:2 |  X:7 Y:0 R:0 T:2 |  X:111 Y:0 R:0 T:0 |  X:45 Y:0 R:0 T:2 |  X:4 Y:0 R:0 T:0 |  X:1 Y:0 R:0 T:3 |  X:2 Y:0 R:2 T:1 |  X:-122 Y:-12 R:0 T:3 |  X:-73 Y:0 R:1 T:1 |
# -------------------------------- 12 GEN ---------------------------------------
# Average pop quality: 147.865
# HIGHEST QUALITY IN GENERATION: 271
# Backpack: X:-68 Y:45 R:1 T:0 |  X:-4 Y:0 R:1 T:3 |  X:1 Y:0 R:0 T:2 |  X:6 Y:0 R:0 T:3 |  X:48 Y:58 R:0 T:2 |  X:0 Y:0 R:3 T:2 |  X:5 Y:0 R:1 T:2 |  X:26 Y:0 R:1 T:1 |  X:21 Y:0 R:0 T:0 |  X:2 Y:0 R:1 T:3 |  X:-65 Y:0 R:1 T:0 |  X:49 Y:13 R:0 T:2 |  X:58 Y:0 R:1 T:0 |  X:-84 Y:87 R:1 T:4 |  X:49 Y:0 R:1 T:0 |  X:-75 Y:0 R:1 T:0 |  X:6 Y:0 R:2 T:2 |  X:9 Y:0 R:1 T:4 |  X:7 Y:0 R:1 T:3 |  X:2 Y:0 R:1 T:1 |  X:0 Y:0 R:0 T:3 |  X:6 Y:0 R:0 T:2 |  X:-8 Y:58 R:1 T:2 |  X:29 Y:0 R:0 T:0 |  X:-75 Y:10 R:0 T:2 |  X:61 Y:0 R:3 T:0 |  X:-72 Y:36 R:1 T:3 |  X:5 Y:0 R:0 T:1 |  X:52 Y:0 R:0 T:3 |  X:1 Y:0 R:1 T:1 |
# -------------------------------- 13 GEN ---------------------------------------
# Average pop quality: 156.989
# HIGHEST QUALITY IN GENERATION: 276
# Backpack: X:-87 Y:-116 R:1 T:0 |  X:7 Y:0 R:3 T:3 |  X:1 Y:0 R:0 T:2 |  X:3 Y:0 R:2 T:3 |  X:13 Y:0 R:0 T:2 |  X:-23 Y:-112 R:0 T:2 |  X:8 Y:0 R:0 T:2 |  X:12 Y:1 R:0 T:1 |  X:95 Y:0 R:0 T:0 |  X:9 Y:0 R:0 T:3 |  X:1 Y:0 R:0 T:0 |  X:6 Y:0 R:0 T:2 |  X:111 Y:0 R:1 T:0 |  X:122 Y:45 R:0 T:4 |  X:-48 Y:0 R:0 T:0 |  X:112 Y:-11 R:2 T:0 |  X:104 Y:-1 R:3 T:2 |  X:-6 Y:0 R:0 T:4 |  X:-7 Y:-113 R:1 T:3 |  X:38 Y:0 R:0 T:1 |  X:6 Y:0 R:1 T:3 |  X:6 Y:0 R:0 T:2 |  X:7 Y:0 R:0 T:2 |  X:42 Y:0 R:0 T:0 |  X:42 Y:0 R:2 T:2 |  X:52 Y:117 R:0 T:0 |  X:7 Y:4 R:0 T:3 |  X:-18 Y:0 R:2 T:1 |  X:1 Y:0 R:3 T:3 |  X:8 Y:0 R:0 T:1 |
# -------------------------------- 14 GEN ---------------------------------------
# Average pop quality: 167.5525
# HIGHEST QUALITY IN GENERATION: 285
# Backpack: X:-58 Y:0 R:3 T:0 |  X:0 Y:0 R:0 T:3 |  X:1 Y:0 R:0 T:2 |  X:-1 Y:0 R:1 T:3 |  X:-80 Y:1 R:0 T:2 |  X:29 Y:0 R:1 T:2 |  X:15 Y:0 R:1 T:2 |  X:56 Y:0 R:2 T:1 |  X:9 Y:0 R:0 T:0 |  X:125 Y:19 R:0 T:3 |  X:24 Y:0 R:3 T:0 |  X:3 Y:0 R:1 T:2 |  X:17 Y:39 R:1 T:0 |  X:26 Y:0 R:0 T:4 |  X:13 Y:0 R:3 T:0 |  X:127 Y:-16 R:0 T:0 |  X:1 Y:0 R:1 T:2 |  X:14 Y:0 R:0 T:4 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:3 T:1 |  X:2 Y:0 R:1 T:3 |  X:-17 Y:6 R:0 T:2 |  X:5 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:0 |  X:-2 Y:7 R:0 T:2 |  X:48 Y:0 R:3 T:0 |  X:0 Y:0 R:0 T:3 |  X:37 Y:120 R:1 T:1 |  X:3 Y:0 R:0 T:3 |  X:17 Y:-27 R:1 T:1 |
# -------------------------------- 15 GEN ---------------------------------------
# Average pop quality: 177.0385
# HIGHEST QUALITY IN GENERATION: 335
# Backpack: X:-20 Y:3 R:0 T:0 |  X:5 Y:0 R:2 T:3 |  X:7 Y:0 R:3 T:2 |  X:-9 Y:60 R:0 T:3 |  X:4 Y:0 R:0 T:2 |  X:49 Y:1 R:0 T:2 |  X:2 Y:0 R:3 T:2 |  X:0 Y:0 R:1 T:1 |  X:9 Y:0 R:0 T:0 |  X:125 Y:19 R:0 T:3 |  X:24 Y:0 R:3 T:0 |  X:3 Y:0 R:1 T:2 |  X:17 Y:39 R:1 T:0 |  X:26 Y:0 R:0 T:4 |  X:13 Y:0 R:3 T:0 |  X:127 Y:-16 R:0 T:0 |  X:1 Y:0 R:1 T:2 |  X:14 Y:0 R:0 T:4 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:3 T:1 |  X:2 Y:0 R:1 T:3 |  X:-1 Y:6 R:0 T:2 |  X:5 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:0 |  X:-2 Y:5 R:0 T:2 |  X:48 Y:0 R:3 T:0 |  X:0 Y:0 R:0 T:3 |  X:37 Y:120 R:0 T:1 |  X:3 Y:0 R:0 T:3 |  X:17 Y:-91 R:1 T:1 |
# -------------------------------- 16 GEN ---------------------------------------
# Average pop quality: 185.033
# HIGHEST QUALITY IN GENERATION: 305
# Backpack: X:52 Y:0 R:0 T:0 |  X:1 Y:0 R:1 T:3 |  X:6 Y:0 R:3 T:2 |  X:1 Y:0 R:1 T:3 |  X:7 Y:0 R:1 T:2 |  X:54 Y:0 R:1 T:2 |  X:16 Y:0 R:0 T:2 |  X:1 Y:0 R:1 T:1 |  X:-41 Y:8 R:1 T:0 |  X:7 Y:0 R:1 T:3 |  X:-2 Y:3 R:2 T:0 |  X:63 Y:0 R:3 T:2 |  X:72 Y:-110 R:0 T:0 |  X:90 Y:0 R:3 T:4 |  X:9 Y:0 R:0 T:0 |  X:40 Y:0 R:0 T:0 |  X:-56 Y:20 R:0 T:2 |  X:-60 Y:1 R:3 T:4 |  X:12 Y:0 R:1 T:3 |  X:5 Y:0 R:0 T:1 |  X:3 Y:0 R:1 T:3 |  X:119 Y:0 R:0 T:2 |  X:2 Y:0 R:0 T:2 |  X:2 Y:0 R:3 T:0 |  X:9 Y:0 R:1 T:2 |  X:-107 Y:105 R:0 T:0 |  X:0 Y:0 R:3 T:3 |  X:2 Y:0 R:0 T:1 |  X:3 Y:0 R:0 T:3 |  X:69 Y:-108 R:2 T:1 |
# -------------------------------- 17 GEN ---------------------------------------
# Average pop quality: 193.774
# HIGHEST QUALITY IN GENERATION: 346
# Backpack: X:-3 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:2 |  X:7 Y:0 R:0 T:3 |  X:3 Y:0 R:2 T:2 |  X:9 Y:0 R:2 T:2 |  X:7 Y:0 R:0 T:2 |  X:82 Y:0 R:0 T:1 |  X:13 Y:4 R:0 T:0 |  X:0 Y:0 R:0 T:3 |  X:-104 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:1 T:0 |  X:1 Y:0 R:1 T:4 |  X:83 Y:0 R:1 T:0 |  X:-81 Y:-113 R:0 T:0 |  X:-35 Y:-55 R:0 T:2 |  X:-74 Y:-72 R:2 T:4 |  X:1 Y:0 R:1 T:3 |  X:7 Y:0 R:3 T:1 |  X:11 Y:0 R:3 T:3 |  X:0 Y:0 R:2 T:2 |  X:2 Y:0 R:0 T:2 |  X:54 Y:0 R:3 T:0 |  X:1 Y:0 R:1 T:2 |  X:4 Y:0 R:3 T:0 |  X:71 Y:4 R:0 T:3 |  X:-18 Y:1 R:2 T:1 |  X:1 Y:0 R:3 T:3 |  X:8 Y:0 R:2 T:1 |
# -------------------------------- 18 GEN ---------------------------------------
# Average pop quality: 201.367
# HIGHEST QUALITY IN GENERATION: 360
# Backpack: X:-3 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:2 |  X:7 Y:0 R:1 T:3 |  X:2 Y:0 R:2 T:2 |  X:9 Y:0 R:2 T:2 |  X:7 Y:0 R:0 T:2 |  X:86 Y:0 R:0 T:1 |  X:9 Y:4 R:0 T:0 |  X:0 Y:0 R:0 T:3 |  X:-112 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:1 T:0 |  X:39 Y:51 R:1 T:4 |  X:-45 Y:0 R:0 T:0 |  X:-109 Y:121 R:1 T:0 |  X:23 Y:0 R:0 T:2 |  X:53 Y:0 R:3 T:4 |  X:3 Y:0 R:3 T:3 |  X:122 Y:-41 R:1 T:1 |  X:0 Y:0 R:0 T:3 |  X:1 Y:0 R:0 T:2 |  X:6 Y:0 R:0 T:2 |  X:11 Y:62 R:3 T:0 |  X:69 Y:0 R:1 T:2 |  X:-80 Y:0 R:1 T:0 |  X:3 Y:0 R:1 T:3 |  X:7 Y:0 R:0 T:1 |  X:3 Y:0 R:1 T:3 |  X:127 Y:0 R:3 T:1 |
# -------------------------------- 19 GEN ---------------------------------------
# Average pop quality: 209.74
# HIGHEST QUALITY IN GENERATION: 336
# Backpack: X:7 Y:0 R:2 T:0 |  X:6 Y:0 R:3 T:3 |  X:3 Y:0 R:3 T:2 |  X:7 Y:0 R:0 T:3 |  X:118 Y:1 R:1 T:2 |  X:6 Y:0 R:0 T:2 |  X:4 Y:0 R:0 T:2 |  X:7 Y:0 R:1 T:1 |  X:1 Y:0 R:1 T:0 |  X:68 Y:0 R:3 T:3 |  X:7 Y:0 R:0 T:0 |  X:0 Y:0 R:2 T:2 |  X:103 Y:0 R:0 T:0 |  X:83 Y:0 R:1 T:4 |  X:52 Y:-94 R:0 T:0 |  X:2 Y:7 R:1 T:0 |  X:1 Y:0 R:0 T:2 |  X:6 Y:0 R:2 T:4 |  X:0 Y:0 R:0 T:3 |  X:1 Y:0 R:3 T:1 |  X:3 Y:0 R:1 T:3 |  X:13 Y:10 R:0 T:2 |  X:5 Y:0 R:1 T:2 |  X:0 Y:58 R:2 T:0 |  X:1 Y:0 R:0 T:2 |  X:-83 Y:32 R:1 T:0 |  X:8 Y:0 R:0 T:3 |  X:83 Y:3 R:1 T:1 |  X:-90 Y:0 R:3 T:3 |  X:102 Y:35 R:1 T:1 |
# -------------------------------- 20 GEN ---------------------------------------
# Average pop quality: 219.393
# HIGHEST QUALITY IN GENERATION: 340
# Backpack: X:15 Y:0 R:3 T:0 |  X:0 Y:0 R:1 T:3 |  X:2 Y:0 R:0 T:2 |  X:12 Y:0 R:1 T:3 |  X:53 Y:17 R:0 T:2 |  X:6 Y:0 R:3 T:2 |  X:21 Y:0 R:1 T:2 |  X:102 Y:127 R:1 T:1 |  X:57 Y:-101 R:1 T:0 |  X:6 Y:0 R:1 T:3 |  X:3 Y:0 R:0 T:0 |  X:0 Y:0 R:3 T:2 |  X:2 Y:0 R:0 T:0 |  X:116 Y:51 R:1 T:4 |  X:-89 Y:26 R:3 T:0 |  X:92 Y:-119 R:0 T:0 |  X:-32 Y:49 R:0 T:2 |  X:44 Y:0 R:0 T:4 |  X:6 Y:0 R:0 T:3 |  X:2 Y:0 R:0 T:1 |  X:0 Y:0 R:0 T:3 |  X:1 Y:0 R:2 T:2 |  X:0 Y:0 R:0 T:2 |  X:2 Y:0 R:0 T:0 |  X:4 Y:0 R:1 T:2 |  X:6 Y:0 R:2 T:0 |  X:7 Y:0 R:1 T:3 |  X:90 Y:73 R:3 T:1 |  X:2 Y:0 R:2 T:3 |  X:3 Y:0 R:0 T:1 |
# -------------------------------- 21 GEN ---------------------------------------
# Average pop quality: 227.076
# HIGHEST QUALITY IN GENERATION: 380
# Backpack: X:47 Y:0 R:0 T:0 |  X:7 Y:0 R:2 T:3 |  X:2 Y:0 R:0 T:2 |  X:94 Y:0 R:3 T:3 |  X:-2 Y:25 R:0 T:2 |  X:7 Y:0 R:1 T:2 |  X:7 Y:0 R:1 T:2 |  X:-57 Y:-23 R:0 T:1 |  X:1 Y:0 R:3 T:0 |  X:6 Y:1 R:1 T:3 |  X:-110 Y:0 R:3 T:0 |  X:1 Y:0 R:0 T:2 |  X:0 Y:0 R:3 T:0 |  X:-118 Y:1 R:1 T:4 |  X:77 Y:0 R:2 T:0 |  X:-30 Y:-61 R:1 T:0 |  X:3 Y:0 R:3 T:2 |  X:-89 Y:-23 R:1 T:4 |  X:7 Y:0 R:2 T:3 |  X:6 Y:0 R:0 T:1 |  X:0 Y:0 R:0 T:3 |  X:1 Y:0 R:2 T:2 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:0 T:0 |  X:4 Y:0 R:1 T:2 |  X:6 Y:0 R:2 T:0 |  X:3 Y:0 R:1 T:3 |  X:90 Y:-55 R:3 T:1 |  X:2 Y:0 R:2 T:3 |  X:3 Y:0 R:0 T:1 |
# -------------------------------- 22 GEN ---------------------------------------
# Average pop quality: 234.5055
# HIGHEST QUALITY IN GENERATION: 350
# Backpack: X:61 Y:0 R:1 T:0 |  X:-1 Y:1 R:2 T:3 |  X:-7 Y:1 R:1 T:2 |  X:5 Y:0 R:1 T:3 |  X:0 Y:0 R:0 T:2 |  X:6 Y:0 R:0 T:2 |  X:-10 Y:91 R:0 T:2 |  X:2 Y:0 R:3 T:1 |  X:21 Y:0 R:0 T:0 |  X:2 Y:0 R:1 T:3 |  X:3 Y:0 R:2 T:0 |  X:0 Y:0 R:1 T:2 |  X:2 Y:0 R:1 T:0 |  X:-76 Y:50 R:1 T:4 |  X:38 Y:26 R:3 T:0 |  X:72 Y:-107 R:0 T:0 |  X:74 Y:21 R:0 T:2 |  X:-118 Y:-4 R:1 T:4 |  X:6 Y:0 R:1 T:3 |  X:5 Y:0 R:2 T:1 |  X:0 Y:0 R:0 T:3 |  X:-86 Y:3 R:2 T:2 |  X:25 Y:0 R:0 T:2 |  X:2 Y:0 R:3 T:0 |  X:7 Y:0 R:1 T:2 |  X:-81 Y:75 R:3 T:0 |  X:2 Y:4 R:1 T:3 |  X:104 Y:3 R:0 T:1 |  X:0 Y:0 R:1 T:3 |  X:8 Y:0 R:0 T:1 |
# -------------------------------- 23 GEN ---------------------------------------
# Average pop quality: 242.615
# HIGHEST QUALITY IN GENERATION: 367
# Backpack: X:-4 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:2 |  X:7 Y:0 R:0 T:3 |  X:3 Y:0 R:2 T:2 |  X:3 Y:0 R:2 T:2 |  X:3 Y:0 R:0 T:2 |  X:82 Y:0 R:0 T:1 |  X:9 Y:4 R:0 T:0 |  X:0 Y:0 R:0 T:3 |  X:-128 Y:1 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:1 T:0 |  X:1 Y:0 R:1 T:4 |  X:28 Y:0 R:1 T:0 |  X:-1 Y:-46 R:0 T:0 |  X:1 Y:0 R:3 T:2 |  X:6 Y:0 R:2 T:4 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:3 T:1 |  X:0 Y:0 R:1 T:3 |  X:1 Y:58 R:0 T:2 |  X:7 Y:0 R:3 T:2 |  X:0 Y:0 R:0 T:0 |  X:3 Y:0 R:0 T:2 |  X:-6 Y:62 R:3 T:0 |  X:-87 Y:0 R:2 T:3 |  X:68 Y:10 R:1 T:1 |  X:0 Y:0 R:2 T:3 |  X:56 Y:0 R:1 T:1 |
# -------------------------------- 24 GEN ---------------------------------------
# Average pop quality: 251.771
# HIGHEST QUALITY IN GENERATION: 371
# Backpack: X:-87 Y:42 R:2 T:0 |  X:7 Y:0 R:2 T:3 |  X:0 Y:0 R:0 T:2 |  X:3 Y:0 R:2 T:3 |  X:1 Y:0 R:3 T:2 |  X:8 Y:1 R:1 T:2 |  X:2 Y:0 R:3 T:2 |  X:29 Y:0 R:2 T:1 |  X:-4 Y:6 R:0 T:0 |  X:0 Y:0 R:3 T:3 |  X:0 Y:0 R:0 T:0 |  X:0 Y:0 R:0 T:2 |  X:115 Y:-33 R:1 T:0 |  X:6 Y:0 R:1 T:4 |  X:-115 Y:2 R:3 T:0 |  X:9 Y:0 R:1 T:0 |  X:6 Y:0 R:1 T:2 |  X:-47 Y:-27 R:1 T:4 |  X:0 Y:0 R:1 T:3 |  X:80 Y:0 R:1 T:1 |  X:6 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:2 |  X:0 Y:0 R:1 T:2 |  X:31 Y:0 R:1 T:0 |  X:94 Y:0 R:0 T:2 |  X:-27 Y:-87 R:0 T:0 |  X:1 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:1 |  X:24 Y:0 R:1 T:3 |  X:9 Y:0 R:2 T:1 |
# -------------------------------- 25 GEN ---------------------------------------
# Average pop quality: 259.0875
# HIGHEST QUALITY IN GENERATION: 386
# Backpack: X:6 Y:0 R:2 T:0 |  X:0 Y:0 R:0 T:3 |  X:6 Y:0 R:1 T:2 |  X:2 Y:0 R:2 T:3 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:0 T:2 |  X:5 Y:0 R:1 T:2 |  X:0 Y:0 R:2 T:1 |  X:30 Y:0 R:1 T:0 |  X:0 Y:0 R:3 T:3 |  X:103 Y:0 R:1 T:0 |  X:55 Y:0 R:2 T:2 |  X:-88 Y:7 R:0 T:0 |  X:0 Y:0 R:0 T:4 |  X:14 Y:0 R:3 T:0 |  X:26 Y:43 R:1 T:0 |  X:63 Y:0 R:0 T:2 |  X:119 Y:0 R:3 T:4 |  X:6 Y:0 R:3 T:3 |  X:1 Y:0 R:2 T:1 |  X:1 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:2 |  X:2 Y:0 R:0 T:2 |  X:-115 Y:0 R:0 T:0 |  X:6 Y:0 R:0 T:2 |  X:-61 Y:14 R:1 T:0 |  X:1 Y:0 R:2 T:3 |  X:-7 Y:0 R:1 T:1 |  X:1 Y:0 R:2 T:3 |  X:4 Y:0 R:0 T:1 |
# -------------------------------- 26 GEN ---------------------------------------
# Average pop quality: 265.9445
# HIGHEST QUALITY IN GENERATION: 400
# Backpack: X:0 Y:0 R:0 T:0 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:0 T:2 |  X:2 Y:0 R:1 T:3 |  X:8 Y:0 R:1 T:2 |  X:4 Y:0 R:0 T:2 |  X:7 Y:0 R:3 T:2 |  X:0 Y:0 R:3 T:1 |  X:64 Y:0 R:3 T:0 |  X:3 Y:0 R:3 T:3 |  X:-35 Y:0 R:0 T:0 |  X:0 Y:0 R:1 T:2 |  X:8 Y:0 R:1 T:0 |  X:-54 Y:-99 R:2 T:4 |  X:15 Y:0 R:1 T:0 |  X:-46 Y:0 R:3 T:0 |  X:3 Y:0 R:0 T:2 |  X:45 Y:0 R:1 T:4 |  X:7 Y:0 R:2 T:3 |  X:2 Y:0 R:0 T:1 |  X:0 Y:0 R:0 T:3 |  X:1 Y:0 R:2 T:2 |  X:0 Y:0 R:0 T:2 |  X:2 Y:0 R:2 T:0 |  X:4 Y:0 R:3 T:2 |  X:2 Y:0 R:2 T:0 |  X:7 Y:0 R:3 T:3 |  X:88 Y:-63 R:0 T:1 |  X:26 Y:63 R:0 T:3 |  X:-11 Y:110 R:0 T:1 |
# -------------------------------- 27 GEN ---------------------------------------
# Average pop quality: 273.0975
# HIGHEST QUALITY IN GENERATION: 390
# Backpack: X:-65 Y:-70 R:2 T:0 |  X:0 Y:0 R:0 T:3 |  X:6 Y:0 R:2 T:2 |  X:3 Y:0 R:1 T:3 |  X:8 Y:0 R:0 T:2 |  X:5 Y:0 R:3 T:2 |  X:1 Y:0 R:3 T:2 |  X:0 Y:0 R:0 T:1 |  X:-27 Y:0 R:2 T:0 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:0 T:0 |  X:-17 Y:21 R:3 T:2 |  X:0 Y:0 R:0 T:0 |  X:-26 Y:1 R:2 T:4 |  X:-112 Y:0 R:3 T:0 |  X:-83 Y:-25 R:3 T:0 |  X:29 Y:0 R:0 T:2 |  X:120 Y:0 R:0 T:4 |  X:4 Y:0 R:1 T:3 |  X:1 Y:0 R:0 T:1 |  X:0 Y:0 R:2 T:3 |  X:3 Y:0 R:0 T:2 |  X:3 Y:0 R:3 T:2 |  X:0 Y:0 R:0 T:0 |  X:2 Y:0 R:1 T:2 |  X:1 Y:0 R:2 T:0 |  X:1 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:1 |  X:56 Y:0 R:1 T:3 |  X:9 Y:0 R:2 T:1 |
# -------------------------------- 28 GEN ---------------------------------------
# Average pop quality: 281.355
# HIGHEST QUALITY IN GENERATION: 410
# Backpack: X:107 Y:-15 R:2 T:0 |  X:2 Y:0 R:1 T:3 |  X:0 Y:0 R:0 T:2 |  X:3 Y:0 R:2 T:3 |  X:-8 Y:1 R:0 T:2 |  X:7 Y:0 R:0 T:2 |  X:2 Y:0 R:1 T:2 |  X:3 Y:0 R:3 T:1 |  X:-28 Y:0 R:3 T:0 |  X:0 Y:0 R:0 T:3 |  X:4 Y:1 R:0 T:0 |  X:3 Y:0 R:2 T:2 |  X:15 Y:0 R:2 T:0 |  X:-80 Y:0 R:0 T:4 |  X:-127 Y:39 R:0 T:0 |  X:1 Y:0 R:2 T:0 |  X:3 Y:0 R:3 T:2 |  X:49 Y:0 R:3 T:4 |  X:3 Y:0 R:1 T:3 |  X:-91 Y:2 R:0 T:1 |  X:1 Y:0 R:2 T:3 |  X:3 Y:0 R:0 T:2 |  X:3 Y:0 R:2 T:2 |  X:1 Y:0 R:0 T:0 |  X:42 Y:1 R:1 T:2 |  X:-64 Y:0 R:1 T:0 |  X:9 Y:0 R:0 T:3 |  X:-9 Y:5 R:1 T:1 |  X:1 Y:0 R:0 T:3 |  X:0 Y:0 R:0 T:1 |
# -------------------------------- 29 GEN ---------------------------------------
# Average pop quality: 290.63
# HIGHEST QUALITY IN GENERATION: 411
# Backpack: X:0 Y:0 R:2 T:0 |  X:0 Y:0 R:3 T:3 |  X:2 Y:0 R:1 T:2 |  X:6 Y:0 R:0 T:3 |  X:1 Y:0 R:2 T:2 |  X:6 Y:0 R:2 T:2 |  X:2 Y:0 R:2 T:2 |  X:0 Y:0 R:0 T:1 |  X:5 Y:0 R:2 T:0 |  X:3 Y:0 R:0 T:3 |  X:-69 Y:3 R:0 T:0 |  X:-9 Y:1 R:2 T:2 |  X:92 Y:-10 R:0 T:0 |  X:114 Y:0 R:0 T:4 |  X:50 Y:98 R:0 T:0 |  X:-30 Y:5 R:1 T:0 |  X:7 Y:0 R:1 T:2 |  X:5 Y:0 R:2 T:4 |  X:0 Y:0 R:0 T:3 |  X:1 Y:0 R:2 T:1 |  X:3 Y:0 R:1 T:3 |  X:5 Y:2 R:2 T:2 |  X:5 Y:0 R:0 T:2 |  X:32 Y:10 R:0 T:0 |  X:0 Y:0 R:1 T:2 |  X:-19 Y:-23 R:1 T:0 |  X:5 Y:0 R:0 T:3 |  X:1 Y:0 R:0 T:1 |  X:125 Y:0 R:0 T:3 |  X:0 Y:0 R:0 T:1 |
# -------------------------------- 30 GEN ---------------------------------------
# Average pop quality: 299.1625
# HIGHEST QUALITY IN GENERATION: 435
# Backpack: X:1 Y:0 R:3 T:0 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:3 T:2 |  X:7 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:2 |  X:1 Y:0 R:2 T:2 |  X:2 Y:0 R:1 T:2 |  X:6 Y:0 R:1 T:1 |  X:-33 Y:0 R:2 T:0 |  X:0 Y:0 R:1 T:3 |  X:16 Y:0 R:0 T:0 |  X:5 Y:0 R:1 T:2 |  X:2 Y:0 R:1 T:0 |  X:16 Y:58 R:1 T:4 |  X:21 Y:0 R:0 T:0 |  X:33 Y:9 R:3 T:0 |  X:0 Y:0 R:0 T:2 |  X:-112 Y:0 R:1 T:4 |  X:0 Y:0 R:1 T:3 |  X:1 Y:0 R:2 T:1 |  X:1 Y:0 R:1 T:3 |  X:1 Y:0 R:2 T:2 |  X:1 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:0 |  X:-54 Y:5 R:0 T:2 |  X:0 Y:0 R:1 T:0 |  X:6 Y:0 R:0 T:3 |  X:2 Y:0 R:3 T:1 |  X:4 Y:0 R:2 T:3 |  X:7 Y:0 R:0 T:1 |
# -------------------------------- 31 GEN ---------------------------------------
# Average pop quality: 306.2885
# HIGHEST QUALITY IN GENERATION: 420
# Backpack: X:0 Y:0 R:0 T:0 |  X:0 Y:0 R:0 T:3 |  X:1 Y:0 R:3 T:2 |  X:6 Y:0 R:1 T:3 |  X:0 Y:0 R:2 T:2 |  X:0 Y:0 R:2 T:2 |  X:7 Y:0 R:2 T:2 |  X:0 Y:0 R:1 T:1 |  X:69 Y:14 R:0 T:0 |  X:0 Y:0 R:0 T:3 |  X:-122 Y:0 R:0 T:0 |  X:1 Y:0 R:2 T:2 |  X:11 Y:0 R:0 T:0 |  X:-110 Y:3 R:1 T:4 |  X:-119 Y:54 R:0 T:0 |  X:1 Y:0 R:2 T:0 |  X:3 Y:0 R:3 T:2 |  X:25 Y:0 R:3 T:4 |  X:1 Y:0 R:1 T:3 |  X:5 Y:2 R:1 T:1 |  X:1 Y:0 R:2 T:3 |  X:3 Y:0 R:0 T:2 |  X:3 Y:0 R:2 T:2 |  X:1 Y:0 R:0 T:0 |  X:6 Y:0 R:3 T:2 |  X:-53 Y:-113 R:0 T:0 |  X:3 Y:0 R:1 T:3 |  X:6 Y:0 R:1 T:1 |  X:-10 Y:0 R:3 T:3 |  X:4 Y:0 R:3 T:1 |
# -------------------------------- 32 GEN ---------------------------------------
# Average pop quality: 314.0515
# HIGHEST QUALITY IN GENERATION: 431
# Backpack: X:-75 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:3 |  X:4 Y:0 R:1 T:2 |  X:0 Y:0 R:1 T:3 |  X:68 Y:7 R:2 T:2 |  X:3 Y:0 R:3 T:2 |  X:0 Y:0 R:2 T:2 |  X:6 Y:0 R:3 T:1 |  X:-105 Y:-33 R:3 T:0 |  X:8 Y:0 R:0 T:3 |  X:7 Y:0 R:1 T:0 |  X:2 Y:0 R:1 T:2 |  X:3 Y:0 R:0 T:0 |  X:1 Y:0 R:0 T:4 |  X:0 Y:0 R:1 T:0 |  X:3 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:21 Y:0 R:0 T:4 |  X:7 Y:0 R:0 T:3 |  X:0 Y:0 R:0 T:1 |  X:2 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:2 |  X:4 Y:0 R:3 T:0 |  X:3 Y:0 R:0 T:2 |  X:122 Y:0 R:1 T:0 |  X:1 Y:0 R:0 T:3 |  X:0 Y:0 R:3 T:1 |  X:0 Y:0 R:0 T:3 |  X:-119 Y:9 R:0 T:1 |
# -------------------------------- 33 GEN ---------------------------------------
# Average pop quality: 320.4145
# HIGHEST QUALITY IN GENERATION: 440
# Backpack: X:61 Y:14 R:0 T:0 |  X:6 Y:0 R:0 T:3 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:2 |  X:7 Y:0 R:2 T:2 |  X:8 Y:0 R:2 T:1 |  X:0 Y:0 R:0 T:0 |  X:1 Y:0 R:1 T:3 |  X:11 Y:61 R:0 T:0 |  X:1 Y:0 R:3 T:2 |  X:2 Y:0 R:1 T:0 |  X:-12 Y:26 R:3 T:4 |  X:-53 Y:39 R:0 T:0 |  X:3 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:53 Y:0 R:0 T:4 |  X:7 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:1 |  X:2 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:2 |  X:4 Y:0 R:3 T:0 |  X:3 Y:0 R:0 T:2 |  X:90 Y:0 R:1 T:0 |  X:1 Y:0 R:0 T:3 |  X:0 Y:0 R:3 T:1 |  X:0 Y:0 R:0 T:3 |  X:-119 Y:9 R:1 T:1 |
# -------------------------------- 34 GEN ---------------------------------------
# Average pop quality: 325.586
# HIGHEST QUALITY IN GENERATION: 450
# Backpack: X:1 Y:0 R:2 T:0 |  X:5 Y:0 R:1 T:3 |  X:7 Y:0 R:2 T:2 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:2 |  X:7 Y:0 R:2 T:2 |  X:8 Y:0 R:2 T:1 |  X:0 Y:0 R:0 T:0 |  X:1 Y:0 R:1 T:3 |  X:9 Y:61 R:0 T:0 |  X:1 Y:0 R:3 T:2 |  X:2 Y:0 R:1 T:0 |  X:-12 Y:26 R:3 T:4 |  X:-53 Y:39 R:0 T:0 |  X:3 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:53 Y:0 R:0 T:4 |  X:7 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:1 |  X:3 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:2 |  X:4 Y:0 R:3 T:0 |  X:3 Y:0 R:0 T:2 |  X:90 Y:0 R:1 T:0 |  X:1 Y:0 R:0 T:3 |  X:0 Y:0 R:3 T:1 |  X:0 Y:0 R:0 T:3 |  X:-119 Y:9 R:1 T:1 |
# -------------------------------- 35 GEN ---------------------------------------
# Average pop quality: 330.7425
# HIGHEST QUALITY IN GENERATION: 450
# Backpack: X:3 Y:0 R:2 T:0 |  X:5 Y:0 R:1 T:3 |  X:7 Y:0 R:2 T:2 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:2 |  X:7 Y:0 R:2 T:2 |  X:8 Y:0 R:2 T:1 |  X:0 Y:0 R:0 T:0 |  X:1 Y:0 R:1 T:3 |  X:9 Y:61 R:0 T:0 |  X:1 Y:0 R:3 T:2 |  X:2 Y:0 R:1 T:0 |  X:-12 Y:26 R:3 T:4 |  X:-53 Y:39 R:0 T:0 |  X:3 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:117 Y:0 R:0 T:4 |  X:7 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:1 |  X:3 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:2 |  X:4 Y:0 R:3 T:0 |  X:3 Y:0 R:0 T:2 |  X:90 Y:0 R:1 T:0 |  X:1 Y:0 R:2 T:3 |  X:0 Y:0 R:3 T:1 |  X:0 Y:0 R:0 T:3 |  X:73 Y:8 R:1 T:1 |
# -------------------------------- 36 GEN ---------------------------------------
# Average pop quality: 336.9745
# HIGHEST QUALITY IN GENERATION: 446
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 30
#      26     Algo.CreateAndAddPhenotype(blocksFor1stBackpack)
#      29 for i in range(1, 100):
# ---> 30     Algo.Iterate()
#      31     print(f'-------------------------------- {i+1} GEN ---------------------------------------')
#      33 Algo.ListCurrentPhenotypes()
#
# Cell In[1], line 193, in Algorithm.Iterate(self)
#     191 self.PreviousGen = self.Phenotypes
#     192 #self.Imigration(0.1)
# --> 193 parentPair = self.PairParentsUp(0.20)
#     195 print('Backpack:', end="")
#     196 for b in self.Phenotypes[self.BestSpecimenID]:
#
# Cell In[1], line 94, in Algorithm.PairParentsUp(self, biasParameter, incestSwitch)
#      92 if((qualityOfPotMate > lowerRange) and (qualityOfPotMate < higherRange) and potentialMateId != self.Phenotypes.index(backpack)):
#      93     parentPairs.append((parentId, potentialMateId))
# ---> 94     break
#      95 elif(i > MAX_PAIRING_ATTEMPTS):
#      96     parentPairs.append((parentId, potentialMateId)) #if paring fails, just adds random
#
# KeyboardInterrupt:
