# %%
import numpy as np
import random

MAX_PAIRING_ATTEMPTS = 100
MUTATION_BITFLIP_CHANCE = 1/32

def terminationCondition():
    return True

#simpler block for testing
class Block2:
    def __init__(self, dim):
        self.type = 0
        self.rot = np.zeros((dim - 1,), dtype=int) 
        self.X = np.zeros((dim,), dtype=int)

class Algorithm:
    def __init__(self, dimensionality, typeValueArray):
        self.blockSetup = []
        self.typeValueArray = typeValueArray
        self.BlockPhenotype = [] # array of arrays of phenotypes in !!BINARY!!
        self.Dimensionality = dimensionality
        #rotation: 2 bits per dimension - 1 (since we do 0: 00 degrees, 01 = 90, 10 = 180, 11 = 270)
        #1 bit for if inside backpack or not
        #don't remember max backpack size, will assume it to be char, so 8 bits per coordinate
        self.rotationStride = 0 
        self.coordinatesStride =  (dimensionality - 1)*2 

        #collection that stores phenotypes (backpacks)
        #backpacks are an array of (blockBinary, type)
        self.Phenotypes = []
        self.PreviousGen = []
        self.BestSpecimenID = 0

    #creates a backpack from [] of blocks, ONLY CALL AT CREATION NOT AFTER ITERATING
    def CreateAndAddPhenotype(self, blocks):
        backpack = []
        for b in blocks:
            backpack.append((self.__translateBlockToBinary(b), b.type))

        self.Phenotypes.append(backpack)

    def ListCurrentPhenotypes(self):
        for a in self.Phenotypes:
            print('Backpack:', end="")
            for b in a:
                c =  self.__translateBinaryToBlock(b[0])
                print(f' X:{c.X[0]} Y:{c.X[1]} R:{c.rot[0]} | ', end="")
            print('\n', end="")

    #biasParameter decides how "wide" the interval around quality of one specimen from which partner is accepted is
    def PairParentsUp(self, biasParameter, incestSwitch = 0):
        parentPairs = [] #format parentPairs[par1] = par2, int array
        
        highestSpecimenQuality = 0
        self.BestSpecimenID = 0
        sum = 0
        for backpack in self.Phenotypes:
            a = self.QualityFunction(backpack)
            sum += a
            if a > highestSpecimenQuality:
                self.BestSpecimenID = self.Phenotypes.index(backpack)
                highestSpecimenQuality = a

        avgQuality = sum/len(self.Phenotypes)
        print(f'Average pop quality: {avgQuality}')

        print(f'HIGHEST QUALITY IN GENERATION: {highestSpecimenQuality}')

        parentsIds = []
        for i in range(0, len(self.Phenotypes)):
            par1Id = random.randint(0, len(self.Phenotypes)-1)
            par2Id = random.randint(0, len(self.Phenotypes)-1)
            
            par1Quality = self.QualityFunction(self.Phenotypes[par1Id])
            par2Quality = self.QualityFunction(self.Phenotypes[par2Id])

            if(par1Quality >= par2Quality):
                parentsIds.append(par1Id)
            else:
                parentsIds.append(par2Id)

        for parentId in parentsIds:
            specimenQuality = self.QualityFunction(self.Phenotypes[parentId])
            lowerRange = specimenQuality - specimenQuality*biasParameter
            higherRange = specimenQuality + specimenQuality*biasParameter

            while True:
                potentialMateId = random.randint(0, len(self.Phenotypes)-1)
                qualityOfPotMate = self.QualityFunction(self.Phenotypes[potentialMateId])

                if((qualityOfPotMate > lowerRange) and (qualityOfPotMate < higherRange) and potentialMateId != self.Phenotypes.index(backpack)):
                    parentPairs.append((parentId, potentialMateId))
                    break
                elif(i > MAX_PAIRING_ATTEMPTS):
                    parentPairs.append((parentId, potentialMateId)) #if paring fails, just adds random
                    break
                i=i+1


        return parentPairs


    #checks how much value we store inside a backpack
    #takes negative values based on how much "illegal" the configuration is
    def QualityFunction(self, backpack): #typeValueArray is array that stores costs for given types
        quality = 0
        #here we need to check legality of a backpack
        for blockTuple in backpack:
            if(self.isInsideBackpack(blockTuple)):
                quality += self.typeValueArray[blockTuple[1]] 
            #generally, the alogorith will decide if the block is inside by moving coordinates
            #so no need for special bit for "isInsideBackpack"
        return quality

    #no sensical implementation for testing sake, HARDCODED FOR 2 DIM
    def isInsideBackpack(self, blockTuple):
        block = self.__translateBinaryToBlock(blockTuple[0])

        type = blockTuple[1]

        if(block.X[0] < 10 and block.X[0] > -10 and block.X[1] < 10 and block.X[1] > -10):
            return True
        else:
            return False

    #parentPairs - array[idOfParent1] = idOfParent2
    def OnePointCrossoverRecombination(self, parentPairs, probability):
        #probability = chance for each parent pair to create an offspring by crossover 
        #1 - probabilty = children will be copies of one of the parents
        #returns phenotypes
        newGen = []
        for pair in parentPairs:
            rng = random.random()
            if (rng > probability):
                #crossover - we randomly copy one of the parents
                whichParent = random.random()
                if (whichParent > 0.5):
                    newOne = self.BitFlipMutation(self.Phenotypes[pair[0]], MUTATION_BITFLIP_CHANCE)
                    newGen.append(newOne)
                else:
                    newOne = self.BitFlipMutation(self.Phenotypes[pair[1]], MUTATION_BITFLIP_CHANCE)
                    newGen.append(newOne)
            else: 
                #recombination - we take two parents, split them in a random point.
                combined = []
                length = min(len(self.Phenotypes[pair[0]]), len(self.Phenotypes[pair[1]]))

                splitPoint = random.randint(0, length)

                for j in range(0, splitPoint):
                    combined.append(self.Phenotypes[pair[0]][j])
                for j in range(splitPoint, length):
                    combined.append(self.Phenotypes[pair[1]][j])

                combined = self.BitFlipMutation(combined, MUTATION_BITFLIP_CHANCE)
                newGen.append(combined)
        return newGen

    #flips bits of a phenotype, probability shouldn't be too big
    def BitFlipMutation(self, phenotype, probability): 
        new_phenotype = []
        for i in range(0, len(phenotype)): #over blocks
            newBin = 0b0
            for j in range(int(phenotype[i][0]).bit_length()): #over bits of a block int(my_np_int64)
                bit = (phenotype[i][0] >> j) & 1
                rng = random.random()
                if (rng < probability):
                    bit ^= 1
                newBin |= (bit << j)
            if random.random() < probability: #since above mutation makes binary numbers smaller with many iterations, some chance to grow them
                newBin |= (1 << int(phenotype[i][0]).bit_length())
            new_phenotype.append((newBin, phenotype[i][1]))
        return new_phenotype


    #takes initial block setup, then randomizes and adds to current population, based on its size
    def Imigration(self, percent):
        immigrants = self.blockSetup
        random.shuffle(immigrants)

        for i in range(0, int(percent*len(self.Phenotypes))):
            for b in immigrants:
                b.X[0] = random.randint(0, 400) #set x
                b.X[1] = random.randint(0, 400) #set y
                b.rot[0] = random.randint(0, 1) #doesn't do anything yet so whatever
            self.CreateAndAddPhenotype(immigrants) 


    def Iterate(self):
        self.PreviousGen = self.Phenotypes
        #self.Imigration(0.1)
        parentPair = self.PairParentsUp(0.20)

        print('Backpack:', end="")
        for b in self.Phenotypes[self.BestSpecimenID]:
            c =  self.__translateBinaryToBlock(b[0])
            print(f' X:{c.X[0]} Y:{c.X[1]} R:{c.rot[0]} T:{b[1]} | ', end="")
        print('\n', end="")
        
        self.Phenotypes = self.OnePointCrossoverRecombination(parentPair, 0.75)


    def __translateBlockToBinary(self, block):
        binaryBlock = np.int64(0) #force 64 bit ints, max dimensionality is limited by this

        for i in range(self.Dimensionality-1): #set single rotation bits
            binaryBlock |= (block.rot[i] << 2*i) #i assume rotation is array,

        for i in range(self.Dimensionality):
            binaryBlock |= block.X[i] << (self.coordinatesStride + (i*8))

        return binaryBlock

    def __translateBinaryToBlock(self, blockInt64):
        block = Block2(self.Dimensionality)
        block.X = np.zeros(self.Dimensionality, dtype=np.uint8)
        block.rot = np.zeros(self.Dimensionality-1, dtype=int)
        block.isInside = 0

        for i in range(self.Dimensionality - 1, -1, -1): #set single rotation bits
           block.X[i] = (blockInt64 >> self.coordinatesStride + (i*8) ) & 0xFF # &0xFF masks out bits leftover to the left

        for i in range(self.Dimensionality - 2, -1, -1): #set single rotation bits
           block.rot[i] = (blockInt64 >> (i*2)) & 0b11

        return block

# %%
typeValueArray = [10, 15, 20, 25, 1, 23] #3 type of blocks, 0 - worth 10 etc.

blocksFor1stBackpack = []

Algo = Algorithm(2, typeValueArray)

for j in range(0, 30):
    b = Block2(2)
    b.type = random.randint(0, 4)
    blocksFor1stBackpack.append(b)

Algo.blockSetup = blocksFor1stBackpack.copy()

highestAchivableQuality = 0
for b in blocksFor1stBackpack:
    highestAchivableQuality += typeValueArray[b.type]
    
print(f'HIGHEST ACHIVABLE QUALITY: {highestAchivableQuality}')

#randomize X and Y from all of initial 300 blocks
for i in range(0, 2000):
    for b in blocksFor1stBackpack:
        b.X[0] = random.randint(0, 400) #set x
        b.X[1] = random.randint(0, 400) #set y
        b.rot[0] = random.randint(0, 1) #doesn't do anything yet so whatever
    Algo.CreateAndAddPhenotype(blocksFor1stBackpack) 


for i in range(1, 100):
    Algo.Iterate()
    print(f'-------------------------------- {i+1} GEN ---------------------------------------')

Algo.ListCurrentPhenotypes()
# Out:
# HIGHEST ACHIVABLE QUALITY: 422
# Average pop quality: 1.0245
# HIGHEST QUALITY IN GENERATION: 35
# Backpack: X:162 Y:87 R:1 T:0 |  X:134 Y:83 R:1 T:0 |  X:1 Y:9 R:0 T:2 |  X:210 Y:22 R:1 T:3 |  X:68 Y:85 R:1 T:4 |  X:128 Y:191 R:1 T:3 |  X:91 Y:120 R:0 T:3 |  X:6 Y:79 R:1 T:0 |  X:180 Y:45 R:0 T:2 |  X:128 Y:96 R:0 T:2 |  X:7 Y:179 R:0 T:4 |  X:99 Y:55 R:1 T:3 |  X:19 Y:228 R:1 T:4 |  X:31 Y:103 R:0 T:1 |  X:62 Y:67 R:1 T:3 |  X:85 Y:35 R:0 T:1 |  X:141 Y:125 R:0 T:1 |  X:222 Y:95 R:0 T:0 |  X:213 Y:95 R:0 T:3 |  X:91 Y:56 R:0 T:4 |  X:77 Y:176 R:0 T:4 |  X:29 Y:209 R:1 T:2 |  X:135 Y:140 R:1 T:1 |  X:53 Y:254 R:1 T:1 |  X:72 Y:151 R:0 T:4 |  X:30 Y:59 R:0 T:1 |  X:6 Y:7 R:1 T:1 |  X:69 Y:11 R:0 T:2 |  X:158 Y:190 R:1 T:4 |  X:119 Y:156 R:0 T:2 |
# -------------------------------- 2 GEN ---------------------------------------
# Average pop quality: 1.527
# HIGHEST QUALITY IN GENERATION: 40
# Backpack: X:53 Y:19 R:1 T:0 |  X:121 Y:127 R:1 T:0 |  X:9 Y:7 R:1 T:2 |  X:50 Y:102 R:1 T:3 |  X:249 Y:96 R:0 T:4 |  X:80 Y:81 R:1 T:3 |  X:76 Y:118 R:1 T:3 |  X:13 Y:85 R:1 T:0 |  X:34 Y:123 R:0 T:2 |  X:3 Y:3 R:1 T:2 |  X:107 Y:85 R:0 T:4 |  X:25 Y:30 R:1 T:3 |  X:54 Y:40 R:0 T:4 |  X:199 Y:75 R:0 T:1 |  X:112 Y:129 R:1 T:3 |  X:221 Y:93 R:1 T:1 |  X:0 Y:123 R:0 T:1 |  X:124 Y:221 R:1 T:0 |  X:215 Y:232 R:0 T:3 |  X:108 Y:89 R:0 T:4 |  X:126 Y:3 R:1 T:4 |  X:188 Y:21 R:1 T:2 |  X:9 Y:227 R:1 T:1 |  X:139 Y:163 R:0 T:1 |  X:2 Y:33 R:0 T:4 |  X:10 Y:198 R:0 T:1 |  X:36 Y:110 R:0 T:1 |  X:174 Y:138 R:1 T:2 |  X:205 Y:239 R:0 T:4 |  X:91 Y:58 R:0 T:2 |
# -------------------------------- 3 GEN ---------------------------------------
# Average pop quality: 2.0995
# HIGHEST QUALITY IN GENERATION: 60
# Backpack: X:113 Y:65 R:0 T:0 |  X:247 Y:158 R:0 T:0 |  X:138 Y:138 R:0 T:2 |  X:18 Y:25 R:1 T:3 |  X:1 Y:127 R:0 T:4 |  X:8 Y:1 R:1 T:3 |  X:51 Y:169 R:0 T:3 |  X:35 Y:23 R:0 T:0 |  X:19 Y:90 R:1 T:2 |  X:184 Y:69 R:0 T:2 |  X:183 Y:9 R:0 T:4 |  X:203 Y:41 R:1 T:3 |  X:133 Y:220 R:0 T:4 |  X:199 Y:69 R:0 T:1 |  X:42 Y:59 R:1 T:3 |  X:249 Y:21 R:0 T:1 |  X:2 Y:41 R:1 T:1 |  X:225 Y:7 R:0 T:0 |  X:1 Y:106 R:1 T:3 |  X:97 Y:99 R:0 T:4 |  X:145 Y:38 R:1 T:4 |  X:7 Y:5 R:1 T:2 |  X:97 Y:156 R:1 T:1 |  X:113 Y:170 R:0 T:1 |  X:114 Y:16 R:3 T:4 |  X:4 Y:7 R:1 T:1 |  X:214 Y:107 R:1 T:1 |  X:179 Y:243 R:0 T:2 |  X:245 Y:31 R:1 T:4 |  X:243 Y:236 R:0 T:2 |
# -------------------------------- 4 GEN ---------------------------------------
# Average pop quality: 2.885
# HIGHEST QUALITY IN GENERATION: 45
# Backpack: X:44 Y:99 R:1 T:0 |  X:1 Y:33 R:0 T:0 |  X:55 Y:49 R:1 T:2 |  X:0 Y:23 R:0 T:3 |  X:36 Y:73 R:0 T:4 |  X:104 Y:17 R:0 T:3 |  X:89 Y:183 R:0 T:3 |  X:17 Y:186 R:0 T:0 |  X:181 Y:21 R:1 T:2 |  X:3 Y:7 R:1 T:2 |  X:87 Y:115 R:1 T:4 |  X:188 Y:155 R:0 T:3 |  X:95 Y:224 R:0 T:4 |  X:15 Y:1 R:1 T:1 |  X:8 Y:13 R:1 T:3 |  X:159 Y:72 R:1 T:1 |  X:15 Y:107 R:1 T:1 |  X:45 Y:128 R:0 T:0 |  X:1 Y:7 R:0 T:3 |  X:192 Y:63 R:0 T:4 |  X:122 Y:87 R:0 T:4 |  X:147 Y:48 R:1 T:2 |  X:213 Y:87 R:0 T:1 |  X:118 Y:77 R:0 T:1 |  X:28 Y:220 R:3 T:4 |  X:204 Y:216 R:0 T:1 |  X:137 Y:42 R:2 T:1 |  X:130 Y:246 R:0 T:2 |  X:8 Y:47 R:0 T:4 |  X:93 Y:17 R:1 T:2 |
# -------------------------------- 5 GEN ---------------------------------------
# Average pop quality: 3.7795
# HIGHEST QUALITY IN GENERATION: 50
# Backpack: X:103 Y:189 R:0 T:0 |  X:97 Y:208 R:0 T:0 |  X:173 Y:80 R:1 T:2 |  X:163 Y:69 R:1 T:3 |  X:199 Y:19 R:1 T:4 |  X:112 Y:22 R:1 T:3 |  X:0 Y:4 R:1 T:3 |  X:127 Y:212 R:0 T:0 |  X:2 Y:105 R:0 T:2 |  X:115 Y:12 R:0 T:2 |  X:26 Y:230 R:1 T:4 |  X:210 Y:132 R:0 T:3 |  X:29 Y:55 R:0 T:4 |  X:99 Y:90 R:0 T:1 |  X:176 Y:5 R:0 T:3 |  X:94 Y:73 R:0 T:1 |  X:14 Y:161 R:1 T:1 |  X:228 Y:135 R:1 T:0 |  X:4 Y:2 R:0 T:3 |  X:34 Y:73 R:0 T:4 |  X:69 Y:125 R:0 T:4 |  X:165 Y:8 R:1 T:2 |  X:241 Y:26 R:1 T:1 |  X:125 Y:104 R:3 T:1 |  X:175 Y:217 R:0 T:4 |  X:61 Y:6 R:0 T:1 |  X:76 Y:3 R:0 T:1 |  X:43 Y:194 R:2 T:2 |  X:15 Y:125 R:0 T:4 |  X:160 Y:82 R:0 T:2 |
# -------------------------------- 6 GEN ---------------------------------------
# Average pop quality: 5.0525
# HIGHEST QUALITY IN GENERATION: 60
# Backpack: X:167 Y:183 R:0 T:0 |  X:90 Y:237 R:0 T:0 |  X:103 Y:25 R:1 T:2 |  X:170 Y:99 R:0 T:3 |  X:64 Y:96 R:1 T:4 |  X:93 Y:62 R:0 T:3 |  X:5 Y:2 R:3 T:3 |  X:1 Y:129 R:3 T:0 |  X:49 Y:6 R:0 T:2 |  X:56 Y:109 R:1 T:2 |  X:92 Y:173 R:1 T:4 |  X:157 Y:32 R:3 T:3 |  X:155 Y:61 R:1 T:4 |  X:29 Y:73 R:0 T:1 |  X:119 Y:195 R:3 T:3 |  X:211 Y:14 R:1 T:1 |  X:194 Y:33 R:0 
# Average pop quality: 10.9395
# HIGHEST QUALITY IN GENERATION: 80
# Backpack: X:29 Y:227 R:0 T:0 |  X:6 Y:5 R:1 T:0 |  X:142 Y:200 R:0 T:2 |  X:4 Y:8 R:1 T:3 |  X:117 Y:227 R:1 T:4 |  X:4 Y:0 R:0 T:3 |  X:253 Y:48 R:3 T:3 |  X:121 Y:145 R:1 T:0 |  X:7 Y:8 R:3 T:2 |  X:99 Y:0 R:2 T:2 |  X:99 Y:56 R:0 T:4 |  X:231 Y:167 R:0 T:3 |  X:233 Y:161 R:1 T:4 |  X:237 Y:9 R:0 T:1 |  X:74 Y:168 R:0 T:3 |  X:118 Y:116 R:1 T:1 |  X:243 Y:93 R:0 T:1 |  X:54 Y:39 R:2 T:0 |  X:40 Y:218 R:1 T:3 |  X:97 Y:45 R:0 T:4 |  X:94 Y:241 R:0 T:4 |  X:47 Y:139 R:0 T:2 |  X:7 Y:83 R:1 T:1 |  X:133 Y:163 R:0 T:1 |  X:34 Y:135 R:1 T:4 |  X:132 Y:45 R:0 T:1 |  X:131 Y:13 R:1 T:1 |  X:23 Y:230 R:1 T:2 |  X:179 Y:95 R:3 T:4 |  X:21 Y:25 R:0 T:2 |
# -------------------------------- 10 GEN ---------------------------------------
# Average pop quality: 13.3695
# HIGHEST QUALITY IN GENERATION: 80
# Backpack: X:29 Y:227 R:0 T:0 |  X:6 Y:5 R:3 T:0 |  X:206 Y:200 R:0 T:2 |  X:4 Y:8 R:1 T:3 |  X:117 Y:163 R:1 T:4 |  X:4 Y:0 R:0 T:3 |  X:253 Y:48 R:3 T:3 |  X:121 Y:145 R:1 T:0 |  X:7 Y:8 R:3 T:2 |  X:99 Y:0 R:2 T:2 |  X:99 Y:56 R:0 T:4 |  X:231 Y:167 R:0 T:3 |  X:233 Y:161 R:1 T:4 |  X:239 Y:9 R:0 T:1 |  X:74 Y:168 R:0 T:3 |  X:118 Y:100 R:1 T:1 |  X:242 Y:93 R:0 T:1 |  X:182 Y:103 R:2 T:0 |  X:40 Y:218 R:1 T:3 |  X:97 Y:45 R:0 T:4 |  X:94 Y:241 R:0 T:4 |  X:47 Y:139 R:0 T:2 |  X:7 Y:83 R:1 T:1 |  X:133 Y:163 R:0 T:1 |  X:34 Y:135 R:1 T:4 |  X:140 Y:41 R:0 T:1 |  X:134 Y:13 R:1 T:1 |  X:23 Y:230 R:1 T:2 |  X:22 Y:75 R:3 T:4 |  X:63 Y:120 R:0 T:2 |
# -------------------------------- 11 GEN ---------------------------------------
# Average pop quality: 15.89
# HIGHEST QUALITY IN GENERATION: 60
# Backpack: X:175 Y:247 R:0 T:0 |  X:122 Y:109 R:2 T:0 |  X:71 Y:25 R:1 T:2 |  X:170 Y:107 R:0 T:3 |  X:80 Y:112 R:1 T:4 |  X:237 Y:63 R:0 T:3 |  X:5 Y:1 R:3 T:3 |  X:19 Y:161 R:3 T:0 |  X:1 Y:2 R:0 T:2 |  X:57 Y:117 R:1 T:2 |  X:126 Y:143 R:0 T:4 |  X:6 Y:138 R:0 T:
# -------------------------------- 14 GEN ---------------------------------------
# Average pop quality: 23.526
# HIGHEST QUALITY IN GENERATION: 85
# Backpack: X:0 Y:180 R:0 T:0 |  X:175 Y:238 R:0 T:0 |  X:39 Y:175 R:3 T:2 |  X:161 Y:245 R:1 T:3 |  X:245 Y:239 R:3 T:4 |  X:229 Y:21 R:0 T:3 |  X:2 Y:0 R:3 T:3 |  X:79 Y:244 R:1 T:0 |  X:62 Y:5 R:3 T:2 |  X:226 Y:52 R:3 T:2 |  X:63 Y:203 R:2 T:4 |  X:7 Y:1 R:1 T:3 |  X:61 Y:34 R:2 T:4 |  X:175 Y:104 R:1 T:1 |  X:184 Y:0 R:2 T:3 |  X:63 Y:54 R:3 T:1 |  X:26 Y:210 R:0 T:1 |  X:118 Y:0 R:3 T:0 |  X:106 Y:201 R:3 T:3 |  X:79 Y:246 R:0 T:4 |  X:216 Y:6 R:2 T:4 |  X:152 Y:126 R:0 T:2 |  X:110 Y:251 R:1 T:1 |  X:73 Y:248 R:1 T:1 |  X:61 Y:74 R:0 T:4 |  X:2 Y:7 R:0 T:1 |  X:233 Y:234 R:3 T:1 |  X:0 Y:9 R:1 T:2 |  X:43 Y:68 R:2 T:4 |  X:239 Y:109 R:0 T:2 |
# -------------------------------- 15 GEN ---------------------------------------
# Average pop quality: 26.288
# HIGHEST QUALITY IN GENERATION: 85
# Backpack: X:20 Y:129 R:0 T:0 |  X:152 Y:209 R:3 T:0 |  X:208 Y:250 R:1 T:2 |  X:1 Y:1 R:3 T:3 |  X:87 Y:15 R:1 T:4 |  X:254 Y:156 R:2 T:3 |  X:0 Y:0 R:3 T:3 |  X:49 Y:113 R:0 T:0 |  X:10 Y:183 R:3 T:2 |  X:122 Y:253 R:1 T:2 |  X:141 Y:65 R:1 T:4 |  X:0 Y:202 R:0 T:3 |  X:91 Y:21 R:0 T:4 |  X:38 Y:71 R:2 T:1 |  X:187 Y:25 R:1 T:3 |  X:14 Y:0 R:0 T:1 |  X:146 Y:57 R:1 T:1 |  X:7 Y:6 R:2 T:0 |  X:3 Y:9 R:0 T:3 |  X:91 Y:223 R:2 T:4 |  X:2 Y:40 R:2 T:4 |  X:165 Y:150 R:0 T:2 |  X:161 Y:147 R:1 T:1 |  X:98 Y:116 R:0 T:1 |  X:184 Y:105 R:0 T:4 |  X:97 Y:103 R:0 T:1 |  X:68 Y:98 R:0 T:1 |  X:105 Y:4 R:1 T:2 |  X:149 Y:20 R:3 T:4 |  X:49 Y:231 R:1 T:2 |
# -------------------------------- 16 GEN ---------------------------------------
# Average pop quality: 29.15
# HIGHEST QUALITY IN GENERATION: 85
# -------------------------------- 19 GEN ---------------------------------------
# Average pop quality: 36.6725
# HIGHEST QUALITY IN GENERATION: 110
# Backpack: X:185 Y:81 R:3 T:0 |  X:148 Y:1 R:0 T:0 |  X:3 Y:0 R:1 T:2 |  X:1 Y:0 R:1 T:3 |  X:172 Y:217 R:3 T:4 |  X:2 Y:1 R:1 T:3 |  X:7 Y:7 R:3 T:3 |  X:5 Y:165 R:0 T:0 |  X:117 Y:205 R:1 T:2 |  X:166 Y:12 R:3 T:2 |  X:68 Y:241 R:1 T:4 |  X:69 Y:47 R:0 T:3 |  X:93 Y:94 R:0 T:4 |  X:6 Y:137 R:2 T:1 |  X:237 Y:110 R:0 T:3 |  X:166 Y:183 R:1 T:1 |  X:125 Y:112 R:1 T:1 |  X:61 Y:236 R:1 T:0 |  X:160 Y:255 R:0 T:3 |  X:137 Y:185 R:0 T:4 |  X:155 Y:126 R:1 T:4 |  X:4 Y:174 R:2 T:2 |  X:12 Y:29 R:3 T:1 |  X:7 Y:4 R:1 T:1 |  X:133 Y:217 R:1 T:4 |  X:8 Y:179 R:1 T:1 |  X:133 Y:49 R:2 T:1 |  X:139 Y:213 R:1 T:2 |  X:179 Y:67 R:0 T:4 |  X:213 Y:129 R:0 T:2 |
# -------------------------------- 20 GEN ---------------------------------------
# Average pop quality: 39.4095
# HIGHEST QUALITY IN GENERATION: 110
# Backpack: X:177 Y:81 R:3 T:0 |  X:148 Y:3 R:0 T:0 |  X:3 Y:0 R:1 T:2 |  X:1 Y:0 R:1 T:3 |  X:180 Y:217 R:3 T:4 |  X:2 Y:1 R:1 T:3 |  X:3 Y:7 R:3 T:3 |  X:5 Y:37 R:0 T:0 |  X:53 Y:205 R:1 T:2 |  X:166 Y:4 R:3 T:2 |  X:68 Y:241 R:1 T:4 |  X:69 Y:47 R:0 T:3 |  X:28 Y:94 R:0 T:4 |  X:6 Y:129 R:2 T:1 |  X:237 Y:110 R:0 T:3 |  X:166 Y:183 R:1 T:1 |  X:125 Y:112 R:1 T:1 |  X:61 Y:236 R:1 T:0 |  X:160 Y:255 R:0 T:3 |  X:137 Y:185 R:0 T:4 |  X:155 Y:114 R:1 T:4 |  X:0 Y:174 R:2 T:2 |  X:12 Y:29 R:3 T:1 |  X:7 Y:4 R:1 T:1 |  X:133 Y:217 R:1 T:4 |  X:8 Y:179 R:1 T:1 |  X:133 Y:49 R:2 T:1 |  X:139 Y:213 R:2 T:2 |  X:179 Y:67 R:0 T:4 |  X:213 Y:133 R:0 T:2 |
# -------------------------------- 21 GEN ---------------------------------------
# Average pop quality: 42.0805
# HIGHEST QUALITY IN GENERATION: 115
y:141 R:0 T:4 |  X:123 Y:2 R:3 T:4 |  X:244 Y:115 R:0 T:2 |  X:45 Y:7 R:0 T:1 |  X:131 Y:237 R:0 T:1 |  X:152 Y:108 R:3 T:4 |  X:57 Y:202 R:1 T:1 |  X:114 Y:34 R:2 T:1 |  X:218 Y:77 R:0 T:2 |  X:188 Y:101 R:1 T:4 |  X:191 Y:80 R:2 T:2 |
# -------------------------------- 24 GEN ---------------------------------------
# Average pop quality: 52.383
# HIGHEST QUALITY IN GENERATION: 155
# Backpack: X:83 Y:185 R:1 T:0 |  X:11 Y:137 R:1 T:0 |  X:50 Y:207 R:3 T:2 |  X:5 Y:0 R:2 T:3 |  X:28 Y:219 R:0 T:4 |  X:7 Y:5 R:3 T:3 |  X:6 Y:0 R:1 T:3 |  X:139 Y:148 R:2 T:0 |  X:30 Y:244 R:3 T:2 |  X:236 Y:114 R:0 T:2 |  X:54 Y:122 R:1 T:4 |  X:0 Y:0 R:0 T:3 |  X:112 Y:249 R:1 T:4 |  X:1 Y:0 R:1 T:1 |  X:4 Y:7 R:0 T:3 |  X:84 Y:3 R:0 T:1 |  X:48 Y:14 R:2 T:1 |  X:192 Y:250 R:1 T:0 |  X:90 Y:48 R:0 T:3 |  X:251 Y:90 R:1 T:4 |  X:173 Y:39 R:1 T:4 |  X:150 Y:200 R:0 T:2 |  X:22 Y:140 R:3 T:1 |  X:24 Y:192 R:2 T:1 |  X:67 Y:250 R:3 T:4 |  X:199 Y:143 R:1 T:1 |  X:8 Y:6 R:0 T:1 |  X:75 Y:204 R:3 T:2 |  X:164 Y:23 R:3 T:4 |  X:250 Y:110 R:0 T:2 |
# -------------------------------- 25 GEN ---------------------------------------
# Average pop quality: 55.83
# HIGHEST QUALITY IN GENERATION: 135
# Backpack: X:50 Y:232 R:1 T:0 |  X:31 Y:117 R:1 T:0 |  X:3 Y:5 R:0 T:2 |  X:0 Y:0 R:0 T:3 |  X:129 Y:219 R:3 T:4 |  X:2 Y:1 R:2 T:3 |  X:7 Y:7 R:3 T:3 |  X:5 Y:36 R:0 T:0 |  X:123 Y:129 R:0 T:2 |  X:219 Y:110 R:2 T:2 |  X:55 Y:96 R:1 T:4 |  X:0 Y:0 R:0 T:3 |  X:236 Y:127 R:0 T:4 |  X:61 Y:77 R:3 T:1 |  X:64 Y:4 R:1 T:3 |  X:126 Y:182 R:3 T:1 |  X:172 Y:6 R:2 T:1 |  X:134 Y:202 R:2 T:0 |  X:195 Y:44 R:0 T:3 |  X:194 Y:36 R:1 T:4 |  X:203 Y:181 R:1 T:4 |  X:52 Y:40 R:1 T:2 |  X:4 Y:0 R:3 T:1 |  X:150 Y:70 R:0 T:1 |  X:247 Y:28 R:0 T:4 |  X:253 Y:42 R:2 T:1 |  X:96 Y:2 R:0 T:1 |  X:66 Y:133 R:3 T:2 |  X:132 Y:116 R:2 T:4 |  X:74 Y:45 R:0 T:2 |
# -------------------------------- 26 GEN ---------------------------------------
# Average pop quality: 60.5245
# HIGHEST QUALITY IN GENERATION: 135
# HIGHEST QUALITY IN GENERATION: 181
# Backpack: X:7 Y:78 R:3 T:0 |  X:194 Y:35 R:1 T:0 |  X:5 Y:3 R:1 T:2 |  X:0 Y:6 R:3 T:3 |  X:249 Y:166 R:2 T:4 |  X:5 Y:0 R:2 T:3 |  X:7 Y:0 R:1 T:3 |  X:164 Y:102 R:1 T:0 |  X:72 Y:2 R:3 T:2 |  X:1 Y:0 R:3 T:2 |  X:183 Y:226 R:1 T:4 |  X:0 Y:0 R:1 T:3 |  X:116 Y:127 R:1 T:4 |  X:26 Y:167 R:2 T:1 |  X:0 Y:0 R:0 T:3 |  X:3 Y:0 R:3 T:1 |  X:133 Y:21 R:0 T:1 |  X:120 Y:158 R:1 T:0 |  X:56 Y:6 R:3 T:3 |  X:40 Y:13 R:3 T:4 |  X:6 Y:6 R:2 T:4 |  X:203 Y:247 R:0 T:2 |  X:57 Y:202 R:2 T:1 |  X:159 Y:17 R:2 T:1 |  X:211 Y:5 R:1 T:4 |  X:93 Y:200 R:3 T:1 |  X:218 Y:38 R:0 T:1 |  X:235 Y:13 R:2 T:2 |  X:61 Y:254 R:1 T:4 |  X:171 Y:116 R:3 T:2 |
# -------------------------------- 36 GEN ---------------------------------------
# Average pop quality: 106.6765
# HIGHEST QUALITY IN GENERATION: 185
# Backpack: X:60 Y:138 R:0 T:0 |  X:89 Y:3 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:7 R:2 T:3 |  X:91 Y:83 R:3 T:4 |  X:187 Y:195 R:1 T:3 |  X:3 Y:0 R:3 T:3 |  X:161 Y:234 R:2 T:0 |  X:8 Y:7 R:0 T:2 |  X:1 Y:0 R:2 T:2 |  X:146 Y:197 R:2 T:4 |  X:28 Y:200 R:0 T:3 |  X:227 Y:43 R:1 T:4 |  X:8 Y:0 R:2 T:1 |  X:122 Y:0 R:0 T:3 |  X:187 Y:28 R:0 T:1 |  X:7 Y:0 R:3 T:1 |  X:213 Y:1 R:1 T:0 |  X:3 Y:0 R:1 T:3 |  X:255 Y:241 R:1 T:4 |  X:182 Y:190 R:0 T:4 |  X:7 Y:7 R:1 T:2 |  X:145 Y:237 R:2 T:1 |  X:25 Y:34 R:1 T:1 |  X:93 Y:199 R:0 T:4 |  X:237 Y:192 R:0 T:1 |  X:244 Y:94 R:3 T:1 |  X:60 Y:207 R:1 T:2 |  X:196 Y:181 R:3 T:4 |  X:214 Y:17 R:1 T:2 |
# -------------------------------- 37 GEN ---------------------------------------
# Average pop quality: 111.9375
# HIGHEST QUALITY IN GENERATION: 210
# Backpack: X:39 Y:13 R:2 T:0 |  X:227 Y:52 R:1 T:0 |  X:0 Y:7 R:1 T:2 |  X:0 Y:4 R:2 T:3 |  X:221 Y:167 R:2 T:4 |  X:5 Y:0 R:3 T:3 |  X:3 Y:0 R:1 T:3 |  X:132 Y:116 R:1 T:0 |  X:8 Y:3 R:1 T:2 |  X:1 Y:0 R:3 T:2 |  X:191 Y:226 R:1 T:4 |  X:0 Y:0 R:1 T:3 |  X
# -------------------------------- 43 GEN ---------------------------------------
# Average pop quality: 149.166
# HIGHEST QUALITY IN GENERATION: 242
# Backpack: X:248 Y:229 R:3 T:0 |  X:70 Y:103 R:3 T:0 |  X:7 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:3 |  X:81 Y:5 R:0 T:4 |  X:6 Y:0 R:1 T:3 |  X:3 Y:0 R:2 T:3 |  X:55 Y:161 R:0 T:0 |  X:9 Y:0 R:1 T:2 |  X:1 Y:0 R:1 T:2 |  X:114 Y:24 R:1 T:4 |  X:61 Y:162 R:2 T:3 |  X:8 Y:0 R:3 T:4 |  X:1 Y:0 R:2 T:1 |  X:0 Y:0 R:1 T:3 |  X:82 Y:189 R:3 T:1 |  X:184 Y:244 R:1 T:1 |  X:65 Y:219 R:2 T:0 |  X:1 Y:6 R:1 T:3 |  X:4 Y:0 R:0 T:4 |  X:204 Y:62 R:0 T:4 |  X:6 Y:0 R:0 T:2 |  X:49 Y:251 R:1 T:1 |  X:110 Y:148 R:3 T:1 |  X:98 Y:62 R:2 T:4 |  X:133 Y:198 R:2 T:1 |  X:225 Y:94 R:2 T:1 |  X:51 Y:48 R:2 T:2 |  X:254 Y:222 R:2 T:4 |  X:1 Y:0 R:3 T:2 |
# -------------------------------- 44 GEN ---------------------------------------
# Average pop quality: 155.8485
# HIGHEST QUALITY IN GENERATION: 242
# Backpack: X:248 Y:165 R:3 T:0 |  X:6 Y:103 R:3 T:0 |  X:3 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:3 |  X:81 Y:5 R:0 T:4 |  X:6 Y:0 R:1 T:3 |  X:3 Y:0 R:2 T:3 |  X:55 Y:161 R:0 T:0 |  X:9 Y:0 R:1 T:2 |  X:1 Y:0 R:1 T:2 |  X:114 Y:25 R:1 T:4 |  X:61 Y:162 R:2 T:3 |  X:8 Y:0 R:3 T:4 |  X:1 Y:0 R:2 T:1 |  X:0 Y:0 R:1 T:3 |  X:82 Y:173 R:2 T:1 |  X:184 Y:244 R:1 T:1 |  X:65 Y:219 R:2 T:0 |  X:1 Y:6 R:1 T:3 |  X:4 Y:0 R:0 T:4 |  X:206 Y:62 R:0 T:4 |  X:6 Y:0 R:1 T:2 |  X:49 Y:251 R:1 T:1 |  X:110 Y:144 R:3 T:1 |  X:98 Y:62 R:2 T:4 |  X:133 Y:198 R:2 T:1 |  X:225 Y:30 R:2 T:1 |  X:16 Y:3 R:2 T:2 |  X:28 Y:99 R:1 T:4 |  X:5 Y:0 R:3 T:2 |
# -------------------------------- 45 GEN ---------------------------------------
# Average pop quality: 161.4845
# HIGHEST QUALITY IN GENERATION: 265
# Backpack: X:67 Y:5 R:1 T:0 |  X:6 Y:1 R:1 T:0 |  X:0 Y:0 R:1 T:2 |  X:9 Y:0 R:0 T:3 |  X:86 Y:187 R:2 T:4 |  X:1 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:3 |  X:150 Y:53 R:0 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:2 T:2 |  X:5 Y:97 R:1 T:4 |  X:134 Y:5 R:1 T:3 |  X:253 Y:105 R:2 T:4 |  X:1 Y:0 R:3 T:1 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:0 T:1 |  X:236 Y:145 R:2 T:1 |  X:140 Y:11 R:2 T:0 |  X:3 Y:0 R:0 T:3 |  X:228 Y:126 R:1 T:4 |  X:70 Y:17 R:0 T:4 |  X:64 Y:214 R:1 T:2 |  X:246 Y:3 R:2 T:1 |  X:179 Y:121 R:3 T:1 |  X:247 Y:176 R:3 T:4 |  X:111 Y:1 R:3 T:1 |  X:135 Y:36 R:1 T:1 |  X:0 Y:0 R:2 T:2 |  X:52 Y:59 R:3 T:4 |  X:0 Y:0 R:3 T:2 |
# -------------------------------- 46 GEN ---------------------------------------
# Average pop quality: 166.411
# HIGHEST QUALITY IN GENERATION: 275
# Backpack: X:50 Y:196 R:3 T:0 |  X:160 Y:229 R:2 T:0 |  X:3 Y:0 R:0 T:2 |  X:7 Y:0 R:1 T:3 |  X:11 Y:42 R:2 T:4 |  X:3 Y:0 R:2 T:3 |  X:0 Y:0 R:1 T:3 |  X:255 Y:53 R:0 T:0 |  X:63 Y:233 R:1 T:2 |  X:2 Y:0 R:1 T:2 |  X:182 Y:0 R:0 T:4 |  X:0 Y:0 R:0 T:3 |  X:54 Y:32 R:0 T:4 |  X:3 Y:0 R:2 T:1 |  X:6 Y:0 R:0 T:3 |  X:7 Y:0 R:3 T:1 |  X:88 Y:1 R:2 T:1 |  X:103 Y:0 R:3 T:0 |  X:6 Y:0 R:0 T:3 |  X:27 Y:8 R:0 T:4 |  X:95 Y:59 R:1 T:4 |  X:179 Y:227 R:0 T:2 |  X:0 Y:0 R:3 T:1 |  X:87 Y:93 R:0 T:1 |  X:211 Y:84 R:3 T:4 |  X:254 Y:181 R:3 T:1 |  X:97 Y:198 R:3 T:1 |  X:0 Y:0 R:3 T:2 |  X:120 Y:2 R:3 T:4 |  X:0 Y:0 R:0 T:2 |
# -------------------------------- 47 GEN ---------------------------------------
# Average pop quality: 172.404
# HIGHEST QUALITY IN GENERATION: 270
# Backpack: X:6 Y:0 R:2 T:0 |  X:244 Y:229 R:3 T:0 |  X:0 Y:1 R:0 T:2 |  X:6 Y:0 R:1 T:3 |  X:250 Y:189 R:0 T:4 |  X:2 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:3 |  X:53 Y:164 R:3 T:0 |  X:0 Y:0 R:0 T:2 |  X:1 Y:0 R:3 T:2 |  X:249 Y:126 R:1 T:4 |  X:0 Y:0 R:0 T:3 |  X:116 Y:116 R:1 T:4 |  X:145 Y:166 R:3 T:1 |  X:0 Y:0 R:0 T:3 |  X:3 Y:0 R:2 T:1 |  X:193 Y:4 R:0 T:1 |  X:216 Y:14 R:1 T:0 |  X:6 Y:0 R:3 T:3 |  X:45 Y:97 R:1 T:4 |  X:45 Y:234 R:1 T:4 |  X:59 Y:6 R:2 T:2 |  X:167 Y:69 R:3 T:1 |  X:2 Y:142 R:0 T:1 |  X:184 Y:196 R:3 T:4 |  X:0 Y:0 R:1 T:1 |  X:116 Y:251 R:1 T:1 |  X:4 Y:0 R:3 T:2 |  X:237 Y:155 R:3 T:4 |  X:214 Y:0 R:0 T:2 |
# -------------------------------- 48 GEN ---------------------------------------
# Average pop quality: 177.534
# HIGHEST QUALITY IN GENERATION: 295
# Backpack: X:177 Y:209 R:2 T:0 |  X:163 Y:105 R:3 T:0 |  X:2 Y:0 R:3 T:2 |  X:1 Y:0 R:0 T:3 |  X:188 Y:27 R:0 T:4 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:3 T
R:2 T:0 |  X:3 Y:0 R:0 T:3 |  X:100 Y:127 R:1 T:4 |  X:206 Y:53 R:2 T:4 |  X:72 Y:106 R:0 T:2 |  X:228 Y:2 R:2 T:1 |  X:53 Y:113 R:3 T:1 |  X:225 Y:178 R:3 T:4 |  X:7 Y:0 R:3 T:1 |  X:1 Y:36 R:1 T:1 |  X:0 Y:0 R:0 T:2 |  X:54 Y:51 R:3 T:4 |  X:0 Y:0 R:1 T:2 |
# -------------------------------- 53 GEN ---------------------------------------
# Average pop quality: 204.261
# HIGHEST QUALITY IN GENERATION: 275
# Backpack: X:136 Y:29 R:2 T:0 |  X:115 Y:112 R:3 T:0 |  X:7 Y:0 R:0 T:2 |  X:1 Y:0 R:3 T:3 |  X:248 Y:152 R:1 T:4 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:3 T:3 |  X:97 Y:149 R:1 T:0 |  X:2 Y:0 R:2 T:2 |  X:7 Y:0 R:3 T:2 |  X:191 Y:0 R:0 T:4 |  X:0 Y:0 R:1 T:3 |  X:216 Y:50 R:3 T:4 |  X:1 Y:0 R:1 T:1 |  X:0 Y:0 R:3 T:3 |  X:7 Y:0 R:2 T:1 |  X:37 Y:162 R:3 T:1 |  X:105 Y:105 R:0 T:0 |  X:0 Y:0 R:0 T:3 |  X:127 Y:15 R:0 T:4 |  X:205 Y:7 R:3 T:4 |  X:18 Y:71 R:2 T:2 |  X:70 Y:124 R:3 T:1 |  X:79 Y:60 R:0 T:1 |  X:54 Y:245 R:3 T:4 |  X:6 Y:0 R:0 T:1 |  X:72 Y:123 R:0 T:1 |  X:0 Y:0 R:3 T:2 |  X:74 Y:7 R:1 T:4 |  X:93 Y:180 R:1 T:2 |
# -------------------------------- 54 GEN ---------------------------------------
# Average pop quality: 208.918
# HIGHEST QUALITY IN GENERATION: 295
# Backpack: X:25 Y:0 R:3 T:0 |  X:10 Y:61 R:0 T:0 |  X:4 Y:0 R:2 T:2 |  X:0 Y:0 R:1 T:3 |  X:50 Y:0 R:1 T:4 |  X:2 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:3 |  X:5 Y:163 R:1 T:0 |  X:0 Y:0 R:1 T:2 |  X:3 Y:0 R:2 T:2 |  X:163 Y:68 R:0 T:4 |  X:0 Y:0 R:0 T:3 |  X:122 Y:36 R:3 T:4 |  X:7 Y:0 R:1 T:1 |  X:0 Y:0 R:0 T:3 |  X:6 Y:0 R:2 T:1 |  X:14 Y:16 R:2 T:1 |  X:98 Y:1 R:2 T:0 |  X:3 Y:0 R:0 T:3 |  X:155 Y:121 R:2 T:4 |  X:203 Y:3 R:0 T:4 |  X:132 Y:7 R:1 T:2 |  X:0 Y:0 R:0 T:1 |  X:56 Y:39 R:1 T:1 |  X:50 Y:29 R:1 T:4 |  X:62 Y:1 R:1 T:1 |  X:143 Y:165 R:3 T:1 |  X:0 Y:0 R:0 T:2 |  X:121 Y:186 R:0 T:4 |  X:1 Y:0 R:2 T:2 |
# -------------------------------- 55 GEN ---------------------------------------
# Average pop quality: 214.039
# HIGHEST QUALITY IN GENERATION: 290
# Backpack: X:0 Y:0 R:2 T:0 |  X:119 Y:10 R:0 T:0 |  X:3 Y:0 R:3 T:2 |  X:0 Y:0 R:0 T:3 |  X:240 Y:156 R:1 T:4 |  X:1 Y:0 R:0 T:3 |  X:0 Y:0 R:0 T:3 |  X:24 Y:225 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:1 Y:0 R:3 T:2 |  X:210 Y:29 R:3 T:4 |  X:0 Y:0 R:1 T:3 |  X:68 Y:50 R:2 T:4 |  X:0 Y:0 R:1 T:1 |  X:0 Y:0 R:0 T:3 |  X:2 Y:0 R:2 T:1 |  X:193 Y:4 R:1 T:1 |  X:126 Y:21 R:2 T:0 |  X:3 Y:3 R:3 T:3 |  X:13 Y:20 R:0 T:4 |  X:30 Y:190 R:0 T:4 |  X:180 Y:162 R:0 T:2 |  X:146 Y:26 R:0 T:1 |  X:249 Y:183 R:2 T:1 |  X:105 Y:180 R:0 T:4 |  X:145 Y:9 R:2 T:1 |  X:138 Y:21 R:3 T:1 |  X:0 Y:0 R:3 T:2 |  X:121 Y:3 R:3 T:4 |  X:0 Y:0 R:0 T:2 |
# -------------------------------- 56 GEN ---------------------------------------
# Average pop quality: 218.781
# HIGHEST QUALITY IN GENERATION: 290
# Backpack: X:0 Y:0 R:2 T:0 |  X:119 Y:10 R:0 T:0 |  X:3 Y:0 R:3 T:2 |  X:0 Y:0 R:0 T:3 |  X:244 Y:156 R:1 T:4 |  X:1 Y:0 R:0 T:3 |  X:0 Y:0 R:0 T:3 |  X:24 Y:225 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:1 Y:0 R:3 T:2 |  X:210 Y:29 R:3 T:4 |  X:0 Y:0 R:1 T:3 |  X:68 Y:50 R:2 T:4 |  X:0 Y:0 R:1 T:1 |  X:0 Y:0 R:0 T:3 |  X:2 Y:0 R:2 T:1 |  X:193 Y:4 R:1 T:1 |  X:126 Y:21 R:2 T:0 |  X:3 Y:3 R:3 T:3 |  X:29 Y:4 R:0 T:4 |  X:28 Y:182 R:0 T:4 |  X:180 Y:162 R:0 T:2 |  X:146 Y:27 R:0 T:1 |  X:249 Y:183 R:2 T:1 |  X:105 Y:148 R:0 T:4 |  X:17 Y:9 R:2 T:1 |  X:138 Y:21 R:3 T:1 |  X:0 Y:0 R:3 T:2 |  X:121 Y:3 R:3 T:4 |  X:0 Y:0 R:0 T:2 |
# -------------------------------- 57 GEN ---------------------------------------
# Average pop quality: 222.752
# HIGHEST QUALITY IN GENERATION: 305
# Backpack: X:65 Y:5 R:1 T:0 |  X:7 Y:1 R:1 T:0 |  X:0 Y:0 R:1 T:2 |  X:2 Y:0 R:2 T:3 |  X:195 Y:2 R:3 T:4 |  X:1 Y:0 R:3 T:3 |  X:0 Y:0 R:1 T:3 |  X:192 Y:149 R:0 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:1 T:2 |  X:175 Y:224 R:2 T:4 |  X:0 Y:0 R:1 T:3 |  X:158 Y:160 R:1 T:4 |  X:3 Y:0 R:3 T:1 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:1 |  X:229 Y:49 R:3 T:1 |  X:156 Y:11 R:2 T:0 |  X:3 Y:0 R:2 T:3 |  X:211 Y:57 R:0 T:4 |  X:87 Y:125 R:2 T:4 |  X:3 Y:0 R:3 T:2 |  X:2 Y:0 R:0 T:1 |  X:77 Y:61 R:3 T:1 |  X:236 Y:28 R:2 T:4 |  X:156 Y:169 R:1 T:1 |  X:225 Y:195 R:1 T:1 |  X:240 Y:58 R:1 T:2 |  X:205 Y:22 R:3 T:4 |  X:0 Y:0 R:3 T:2 |
# -------------------------------- 58 GEN ---------------------------------------
# Average pop quality: 227.298
# HIGHEST QUALITY IN GENERATION: 295
# Backpack: X:37 Y:60 R:1 T:0 |  X:94 Y:0 R:2 T:0 |  X:0 Y:0 R:1 T:2 |  X:0 Y:0 R:0 T:3 |  X:195 Y:99 R:1 T:4 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:0 T:3 |  X:1 Y:174 R:0 T:0 |  X:3 Y:0 R:1 T:2 |  X:3 Y:0 R:0 T:2 |  X:177 Y:80 R:3 T:4 |  X:1 Y:0 R:1 T:3 |  X:231 Y:206 R:0 T:4 |  X:0 Y:0 R:1 T:1 |  X:0 Y:0 R:1 T:3 |  X:15 Y:0 R:0 T:1 |  X:5 Y:9 R:0 T:1 |  X:177 Y:98 R:2 T:0 |  X:3 Y:0 R:1 T:3 |  X:64 Y:98 R:0 T:4 |  X:122 Y:5 R:1 T:4 |  X:165 Y:154 R:2 T:2 |  X:7 Y:5 R:1 T:1 |  X:123 Y:162 R:2 T:1 |  X:137 Y:252 R:2 T:4 |  X:145 Y:178 R:1 T:1 |  X:162 Y:37 R:2 T:1 |  X:0 Y:0 R:3 T:2 |  X:56 Y:7 R:3 T:4 |  X:0 Y:0 R:1 T:2 |
# -------------------------------- 59 GEN ---------------------------------------
# Average pop quality: 230.6885
# HIGHEST QUALITY IN GENERATION: 301
# Backpack: X:184 Y:74 R:3 T:0 |  X:231 Y:5 R:1 T:0 |  X:3 Y:0 R:1 T:2 |  X:3 Y:0 R:3 T:3 |  X:0 Y:0 R:1 T:4 |  X:2 Y:0 R:3 T:3 |  X:0 Y:0 R:1 T:3 |  X:14 Y:178 R:2 T:0 |  X:0 Y:0 R:2 T:2 |  X:1 Y:0 R:3 T:2 |  X:114 Y:204 R:1 T:4 |  X:0 Y:0 R:3 T:3 |  X:98 Y:52 R:2 T:4 |  X:0 Y:0 R:0 T:1 |  X:0 Y:0 R:3 T:3 |  X:7 Y:0 R:2 T:1 |  X:153 Y:209 R:2 T:1 |  X:65 Y:27 R:2 T:0 |  X:0 Y:4 R:0 T:3 |  X:68 Y:158 R:1 T:4 |  X:193 Y:244 R:3 T:4 |  X:5 Y:0 R:2 T:2 |  X:157 Y:188 R:0 T:1 |  X:17 Y:56 R:2 T:1 |  X:193 Y:43 R:1 T:4 |  X:246 Y:7 R:0 T:1 |  X:157 Y:7 R:1 T:1 |  X:4 Y:0 R:1 T:2 |  X:22 Y:51 R:2 T:4 |  X:3 Y:0 R:2 T:2 |
# -------------------------------- 60 GEN ---------------------------------------
# Average pop quality: 234.1055
# HIGHEST QUALITY IN GENERATION: 311
# Backpack: X:1 Y:0 R:2 T:0 |  X:228 Y:249 R:2 T:0 |  X:2 Y:0 R:1 T:2 |  X:2 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:4 |  X:2 Y:0 R:3 T:3 |  X:0 Y:0 R:1 T:3 |  X:14 Y:178 R:2 T:0 |  X:0 Y:0 R:2 T:2 |  X:1 Y:0 R:3 T:2 |  X:114 Y:204 R:3 T:4 |  X:0 Y:0 R:3 T:3 |  X:98 Y:52 R:2 T:4 |  X:0 Y:0 R:0 T:1 |  X:0 Y:0 R:3 T:3 |  X:7 Y:0 R:2 T:1 |  X:153 Y:209 R:2 T:1 |  X:65 Y:25 R:2 T:0 |  X:0 Y:4 R:0 T:3 |  X:196 Y:158 R:1 T:4 |  X:193 Y:244 R:3 T:4 |  X:5 Y:0 R:2 T:2 |  X:157 Y:188 R:0 T:1 |  X:17 Y:56 R:3 T:1 |  X:193 Y:43 R:1 T:4 |  X:246 Y:7 R:0 T:1 |  X:141 Y:7 R:1 T:1 |  X:4 Y:0 R:1 T:2 |  X:22 Y:51 R:2 T:4 |  X:3 Y:0 R:2 T:2 |
# -------------------------------- 61 GEN ---------------------------------------
# Average pop quality: 238.161
# HIGHEST QUALITY IN GENERATION: 310
# Backpack: X:3 Y:0 R:2 T:0 |  X:152 Y:58 R:0 T:0 |  X:3 Y:0 R:1 T:2 |  X:2 Y:0 R:0 T:3 |  X:51 Y:8 R:1 T:4 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:3 |  X:14 Y:178 R:2 T:0 |  X:0 Y:0 R:2 T:2 |  X:1 Y:0 R:3 T:2 |  X:114 Y:204 R:3 T:4 |  X:0 Y:0 R:3 T:3 |  X:98 Y:52 R:2 T:4 |  X:0 Y:0 R:0 T:1 |  X:0 Y:0 R:3 T:3 |  X:7 Y:0 R:2 T:1 |  X:153 Y:209 R:2 T:1 |  X:193 Y:25 R:2 T:0 |  X:0 Y:4 R:0 T:3 |  X:196 Y:158 R:1 T:4 |  X:193 Y:245 R:3 T:4 |  X:5 Y:0 R:2 T:2 |  X:157 Y:188 R:0 T:1 |  X:17 Y:56 R:3 T:1 |  X:193 Y:43 R:1 T:4 |  X:242 Y:7 R:0 T:1 |  X:173 Y:15 R:1 T:1 |  X:4 Y:0 R:1 T:2 |  X:150 Y:51 R:2 T:4 |  X:2 Y:0 R:0 T:2 |
# -------------------------------- 62 GEN ---------------------------------------
# Average pop quality: 242.809
# HIGHEST QUALITY IN GENERATION: 305
# Backpack: X:7 Y:0 R:2 T:0 |  X:37 Y:45 R:2 T:0 |  X:7 Y:0 R:3 T:2 |  X:7 Y:0 R:0 T:3 |  X:8 Y:120 R:0 T:4 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:3 T:3 |  X:239 Y:101 R:3 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:1 T:2 |  X:72 Y:212 R:2 T:4 |  X:0 Y:0 R:0 T:3 |  X:134 Y:192 R:3 T:4 |  X:2 Y:0 R:1 T:1 |  X:0 Y:0 R:3 T:3 |  X:120 Y:37 R:0 T:1 |  X:92 Y:124 R:0 T:1 |  X:186 Y:24 R:0 T:0 |  X:3 Y:0 R:0 T:3 |  X:138 Y:213 R:1 T:4 |  X:234 Y:3 R:2 T:4 |  X:44 Y:8 R:0 T:2 |  X:3 Y:0 R:3 T:1 |  X:63 Y:19 R:3 T:1 |  X:48 Y:172 R:1 T:4 |  X:0 Y:0 R:1 T:1 |  X:161 Y:65 R:3 T:1 |  X:4 Y:0 R:3 T:2 |  X:254 Y:2 R:3 T:4 |  X:0 Y:0 R:1 T:2 |
# -------------------------------- 63 GEN ---------------------------------------
# Average pop quality: 246.393
# HIGHEST QUALITY IN GENERATION: 325
# Backpack: X:3 Y:0 R:2 T:0 |  X:156 Y:58 R:1 T:0 |  X:3 Y:0 R:1 T:2 |  X:2 Y:0 R:0 T:3 |  X:35 Y:8 R:1 T:4 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:3 |  X:14 Y:160 R:3 T:0 |  X:0 Y:0 R:2 T:2 |  X:1 Y:0 R:3 T:2 |  X:82 Y:200 R:3 T:4 |  X:0 Y:0 R:3 T:3 |  X:98 Y:52 R:2 T:4 |  X:0 Y:0 R:0 T:1 |  X:0 Y:0 R:3 T:3 |  X:6 Y:0 R:2 T:1 |  X:153 Y:209 R:2 T:1 |  X:193 Y:25 R:2 T:0 |  X:8 Y:4 R:0 T:3 |  X:68 Y:30 R:1 T:4 |  X:193 Y:229 R:3 T:4 |  X:5 Y:0 R:2 T:2 |  X:157 Y:184 R:0 T:1 |  X:224 Y:183 R:2 T:1 |  X:119 Y:240 R:0 T:4 |  X:0 Y:0 R:0 T:1 |  X:200 Y:58 R:3 T:1 |  X:0 Y:0 R:0 T:2 |  X:12 Y:104 R:3 T:4 |  X:8 Y:6 R:2 T:2 |
# -------------------------------- 64 GEN ---------------------------------------
# Average pop quality: 248.994
# HIGHEST QUALITY IN GENERATION: 330
# Backpack: X:1 Y:0 R:3 T:0 |  X:253 Y:118 R:0 T:0 |  X:3 Y:0 R:2 T:2 |  X:3 Y:0 R:1 T:3 |  X:18 Y:1 R:2 T:4 |  X:1 Y:0 R:3 T:3 |  X:0 Y:0 R:3 T:3 |  X:37 Y:135 R:0 T:0 |  X:3 Y:0 R:3 T:2 |  X:0 Y:0 R:1 T:2 |  X:184 Y:255 R:2 T:4 |  X:0 Y:0 R:1 T:3 |  X:147 Y:4 R:3 T:4 |  X:1 Y:0 R:0 T:1 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:1 |  X:227 Y:123 R:1 T:1 |  X:9 Y:0 R:0 T:0 |  X:0 Y:0 R:0 T:3 |  X:249 Y:99 R:1 T:4 |  X:125 Y:1 R:3 T:4 |  X:8 Y:6 R:3 T:2 |  X:133 Y:91 R:1 T:1 |  X:254 Y:27 R:2 T:1 |  X:15 Y:141 R:2 T:4 |  X:4 Y:0 R:2 T:1 |  X:2 Y:0 R:0 T:1 |  X:0 Y:0 R:0 T:2 |  X:166 Y:90 R:1 T:4 |  X:30 Y:125 R:1 T:2 |
# -------------------------------- 65 GEN ---------------------------------------
# Average pop quality: 252.184
# HIGHEST QUALITY IN GENERATION: 325
# Backpack: X:0 Y:0 R:3 T:0 |  X:105 Y:109 R:0 T:0 |  X:7 Y:0 R:3 T:2 |  X:0 Y:0 R:0 T:3 |  X:163 Y:117 R:1 T:4 |  X:0 Y:0 R:2 T:3 |  X:0 Y:0 R:2 T:3 |  X:35 Y:194 R:0 T:0 |  X:4 Y:0 R:0 T:2 |  X:0 Y:0 R:1 T:2 |  X:3 Y:127 R:1 T:4 |  X:0 Y:0 R:3 T:3 |  X:216 Y:107 R:2 T:4 |  X:0 Y:0 R:0 T:1 |  X:3 Y:0 R:0 T:3 |  X:179 Y:176 R:2 T:1 |  X:54 Y:86 R:3 T:1 |  X:22 Y:74 R:2 T:0 |  X:6 Y:0 R:2 T:3 |  X:185 Y:97 R:1 T:4 |  X:109 Y:1 R:3 T:4 |  X:8 Y:6 R:3 T:2 |  X:133 Y:91 R:1 T:1 |  X:254 Y:23 R:2 T:1 |  X:7 Y:140 R:2 T:4 |  X:4 Y:0 R:2 T:1 |  X:0 Y:0 R:0 T:1 |  X:0 Y:0 R:0 T:2 |  X:166 Y:122 R:1 T:4 |  X:0 Y:0 R:1 T:2 |
# -------------------------------- 66 GEN ---------------------------------------
# Average pop quality: 256.131
# HIGHEST QUALITY IN GENERATION: 325
# Backpack: X:1 Y:0 R:0 T:0 |  X:237 Y:50 R:3 T:0 |  X:3 Y:0 R:3 T:2 |  X:3 Y:0 R:0 T:3 |  X:6 Y:42 R:1 T:4 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:0 T:3 |  X:42 Y:175 R:3 T:0 |  X:1 Y:0 R:0 T:2 |  X:0 Y:0 R:3 T:2 |  X:20 Y:0 R:2 T:4 |  X:0 Y:0 R:3 T:3 |  X:159 Y:20 R:1 T:4 |  X:6 Y:0 R:1 T:1 |  X:0 Y:0 R:3 T:3 |  X:0 Y:0 R:0 T:1 |  X:89 Y:11 R:1 T:1 |  X:75 Y:42 R:3 T:0 |  X:3 Y:0 R:2 T:3 |  X:96 Y:42 R:3 T:4 |  X:145 Y:228 R:3 T:4 |  X:9 Y:7 R:3 T:2 |  X:0 Y:0 R:2 T:1 |  X:239 Y:182 R:3 T:1 |  X:209 Y:43 R:1 T:4 |  X:169 Y:162 R:2 T:1 |  X:131 Y:100 R:2 T:1 |  X:0 Y:0 R:1 T:2 |  X:116 Y:2 R:3 T:4 |  X:0 Y:0 R:1 T:2 |
# -------------------------------- 67 GEN ---------------------------------------
# Average pop quality: 259.127
# HIGHEST QUALITY IN GENERATION: 330
# Backpack: X:1 Y:0 R:0 T:0 |  X:0 Y:0 R:0 T:0 |  X:1 Y:0 R:1 T:2 |  X:2 Y:0 R:2 T:3 |  X:168 Y:4 R:2 T:4 |  X:0 Y:0 R:3 T:3 |  X:1 Y:0 R:3 T:3 |  X:241 Y:231 R:0 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:3 T:2 |  X:91 Y:1 R:1 T:4 |  X:0 Y:0 R:1 T:3 |  X:212 Y:35 R:0 T:4 |  X:7 Y:0 R:1 T:1 |  X:0 Y:0 R:0 T:3 |  X:5 Y:0 R:2 T:1 |  X:187 Y:25 R:1 T:1 |  X:245 Y:41 R:0 T:0 |  X:6 Y:0 R:1 T:3 |  X:157 Y:106 R:3 T:4 |  X:254 Y:0 R:3 T:4 |  X:6 Y:0 R:1 T:2 |  X:2 Y:0 R:0 T:1 |  X:251 Y:118 R:1 T:1 |  X:191 Y:193 R:1 T:4 |  X:5 Y:0 R:0 T:1 |  X:238 Y:1 R:3 T:1 |  X:0 Y:0 R:1 T:2 |  X:68 Y:0 R:1 T:4 |  X:159 Y:121 R:2 T:2 |
# -------------------------------- 68 GEN ---------------------------------------
# Average pop quality: 262.3205
# HIGHEST QUALITY IN GENERATION: 330
# Backpack: X:1 Y:0 R:1 T:0 |  X:2 Y:0 R:2 T:0 |  X:3 Y:0 R:0 T:2 |  X:3 Y:0 R:1 T:3 |  X:252 Y:174 R:1 T:4 |  X:0 Y:0 R:2 T:3 |  X:0 Y:0 R:0 T:3 |  X:92 Y:161 R:0 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:3 T:2 |  X:4 Y:16 R:3 T:4 |  X:0 Y:0 R:3 T:3 |  X:199 Y:0 R:0 T:4 |  X:0 Y:0 R:0 T:1 |  X:1 Y:0 R:2 T:3 |  X:3 Y:0 R:3 T:1 |  X:123 Y:47 R:1 T:1 |  X:205 Y:0 R:2 T:0 |  X:7 Y:0 R:2 T:3 |  X:110 Y:62 R:1 T:4 |  X:156 Y:6 R:0 T:4 |  X:2 Y:0 R:1 T:2 |  X:2 Y:0 R:1 T:1 |  X:48 Y:67 R:0 T:1 |  X:77 Y:192 R:1 T:4 |  X:4 Y:6 R:0 T:1 |  X:40 Y:13 R:3 T:1 |  X:1 Y:0 R:2 T:2 |  X:101 Y:0 R:1 T:4 |  X:157 Y:27 R:1 T:2 |
# -------------------------------- 69 GEN ---------------------------------------
# Average pop quality: 265.5285
# HIGHEST QUALITY IN GENERATION: 330
# Backpack: X:2 Y:0 R:1 T:0 |  X:6 Y:0 R:0 T:0 |  X:6 Y:0 R:0 T:2 |  X:7 Y:0 R:2 T:3 |  X:152 Y:20 R:3 T:4 |  X:0 Y:0 R:2 T:3 |  X:0 Y:0 R:1 T:3 |  X:243 Y:183 R:1 T:0 |  X:7 Y:0 R:2 T:2 |  X:0 Y:0 R:3 T:2 |  X:0 Y:78 R:3 T:4 |  X:0 Y:0 R:1 T:3 |  X:106 Y:1 R:2 T:4 |  X:1 Y:0 R:0 T:1 |  X:1 Y:0 R:1 T:3 |  X:0 Y:0 R:0 T:1 |  X:2 Y:39 R:3 T:1 |  X:199 Y:23 R:3 T:0 |  X:2 Y:0 R:0 T:3 |  X:241 Y:7 R:3 T:4 |  X:235 Y:1 R:1 T:4 |  X:109 Y:181 R:0 T:2 |  X:159 Y:0 R:0 T:1 |  X:239 Y:18 R:1 T:1 |  X:164 Y:108 R:0 T:4 |  X:3 Y:0 R:2 T:1 |  X:6 Y:0 R:2 T:1 |  X:0 Y:0 R:0 T:2 |  X:7 Y:15 R:0 T:4 |  X:0 Y:0 R:0 T:2 |
# -------------------------------- 70 GEN ---------------------------------------
# Average pop quality: 268.5875
# HIGHEST QUALITY IN GENERATION: 335
# Backpack: X:0 Y:0 R:1 T:0 |  X:250 Y:142 R:1 T:0 |  X:0 Y:0 R:1 T:2 |  X:1 Y:0 R:0 T:3 |  X:201 Y:46 R:3 T:4 |  X:1 Y:0 R:1 T:3 |  X:0 Y:0 R:0 T:3 |  X:249 Y:134 R:3 T:0 |  X:0 Y:0 R:3 T:2 |  X:7 Y:0 R:3 T:2 |  X:68 Y:15 R:0 T:4 |  X:0 Y:0 R:1 T:3 |  X:129 Y:184 R:2 T:4 |  X:1 Y:0 R:1 T:1 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:3 T:1 |  X:9 Y:0 R:0 T:1 |  X:107 Y:36 R:0 T:0 |  X:7 Y:0 R:0 T:3 |  X:210 Y:30 R:1 T:4 |  X:192 Y:3 R:2 T:4 |  X:4 Y:0 R:3 T:2 |  X:6 Y:0 R:0 T:1 |  X:0 Y:0 R:1 T:1 |  X:234 Y:129 R:2 T:4 |  X:37 Y:193 R:0 T:1 |  X:229 Y:253 R:2 T:1 |  X:0 Y:0 R:0 T:2 |  X:83 Y:2 R:3 T:4 |  X:193 Y:16 R:0 T:2 |
# -------------------------------- 71 GEN ---------------------------------------
# Average pop quality: 271.279
# HIGHEST QUALITY IN GENERATION: 335
# Backpack: X:1 Y:0 R:3 T:0 |  X:0 Y:0 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:0 T:3 |  X:155 Y:23 R:3 T:4 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:3 T:3 |  X:50 Y:9 R:2 T:0 |  X:0 Y:0 R:3 T:2 |  X:3 Y:0 R:3 T:2 |  X:234 Y:99 R:3 T:4 |  X:1 Y:0 R:2 T:3 |  X:116 Y:16 R:2 T:4 |  X:6 Y:0 R:1 T:1 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:0 T:1 |  X:229 Y:163 R:0 T:1 |  X:148 Y:3 R:1 T:0 |  X:7 Y:0 R:0 T:3 |  X:76 Y:188 R:1 T:4 |  X:196 Y:15 R:3 T:4 |  X:2 Y:0 R:0 T:2 |  X:0 Y:0 R:1 T:1 |  X:124 Y:39 R:2 T:1 |  X:240 Y:22 R:1 T:4 |  X:85 Y:24 R:3 T:1 |  X:252 Y:11 R:1 T:1 |  X:0 Y:0 R:0 T:2 |  X:24 Y:2 R:1 T:4 |  X:3 Y:0 R:3 T:2 |
# -------------------------------- 72 GEN ---------------------------------------
# Average pop quality: 273.819
# HIGHEST QUALITY IN GENERATION: 335
# Backpack: X:0 Y:0 R:3 T:0 |  X:234 Y:53 R:0 T:0 |  X:0 Y:0 R:2 T:2 |  X:0 Y:0 R:1 T:3 |  X:66 Y:78 R:1 T:4 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:2 T:3 |  X:220 Y:112 R:1 T:0 |  X:0 Y:0 R:0 T:2 |  X:1 Y:0 R:1 T:2 |  X:169 Y:71 R:1 T:4 |  X:0 Y:0 R:1 T:3 |  X:145 Y:98 R:3 T:4 |  X:0 Y:0 R:0 T:1 |  X:0 Y:0 R:3 T:3 |  X:6 Y:0 R:2 T:1 |  X:49 Y:218 R:1 T:1 |  X:41 Y:127 R:1 T:0 |  X:1 Y:0 R:1 T:3 |  X:118 Y:252 R:3 T:4 |  X:27 Y:3 R:0 T:4 |  X:5 Y:0 R:2 T:2 |  X:7 Y:0 R:1 T:1 |  X:133 Y:172 R:0 T:1 |  X:164 Y:122 R:0 T:4 |  X:3 Y:0 R:2 T:1 |  X:4 Y:0 R:0 T:1 |  X:1 Y:0 R:2 T:2 |  X:198 Y:140 R:2 T:4 |  X:82 Y:115 R:0 T:2 |
# -------------------------------- 73 GEN ---------------------------------------
# Average pop quality: 276.8475
# HIGHEST QUALITY IN GENERATION: 336
# Backpack: X:0 Y:0 R:1 T:0 |  X:25 Y:23 R:0 T:0 |  X:1 Y:0 R:3 T:2 |  X:7 Y:0 R:1 T:3 |  X:95 Y:242 R:0 T:4 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:2 T:3 |  X:5 Y:3 R:2 T:0 |  X:0 Y:0 R:2 T:2 |  X:1 Y:0 R:3 T:2 |  X:39 Y:221 R:0 T:4 |  X:0 Y:0 R:0 T:3 |  X:211 Y:187 R:0 T:4 |  X:0 Y:0 R:1 T:1 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:0 T:1 |  X:119 Y:27 R:3 T:1 |  X:92 Y:7 R:2 T:0 |  X:2 Y:0 R:0 T:3 |  X:197 Y:182 R:0 T:4 |  X:197 Y:245 R:3 T:4 |  X:5 Y:0 R:3 T:2 |  X:0 Y:0 R:0 T:1 |  X:34 Y:53 R:0 T:1 |  X:184 Y:56 R:2 T:4 |  X:198 Y:0 R:0 T:1 |  X:103 Y:180 R:3 T:1 |  X:0 Y:0 R:0 T:2 |  X:9 Y:2 R:3 T:4 |  X:0 Y:0 R:3 T:2 |
# -------------------------------- 74 GEN ---------------------------------------
# Average pop quality: 279.9135
# HIGHEST QUALITY IN GENERATION: 345
# Backpack: X:1 Y:0 R:3 T:0 |  X:6 Y:0 R:3 T:0 |  X:0 Y:0 R:0 T:2 |  X:0 Y:0 R:1 T:3 |  X:219 Y:19 R:1 T:4 |  X:0 Y:0 R:1 T:3 |  X:0 Y:0 R:1 T:3 |  X:14 Y:162 R:3 T:0 |  X:1 Y:0 R:3 T:2 |  X:1 Y:0 R:0 T:2 |  X:203 Y:216 R:1 T:4 |  X:0 Y:0 R:3 T:3 |  X:181 Y:5 R:2 T:4 |  X:1 Y:0 R:1 T:1 |  X:0 Y:0 R:3 T:3 |  X:2 Y:0 R:3 T:1 |  X:147 Y:234 R:1 T:1 |  X:138 Y:118 R:3 T:0 |  X:5 Y:0 R:2 T:3 |  X:107 Y:110 R:1 T:4 |  X:1 Y:53 R:0 T:4 |  X:204 Y:238 R:1 T:2 |  X:6 Y:0 R:3 T:1 |  X:47 Y:1 R:0 T:1 |  X:71 Y:76 R:3 T:4 |  X:7 Y:0 R:2 T:1 |  X:7 Y:0 R:2 T:1 |  X:0 Y:0 R:0 T:2 |  X:101 Y:1 R:1 T:4 |  X:1 Y:0 R:1 T:2 |
# -------------------------------- 75 GEN ---------------------------------------
# Average pop quality: 282.52
# HIGHEST QUALITY IN GENERATION: 345
# Backpack: X:2 Y:0 R:3 T:0 |  X:0 Y:1 R:3 T:0 |  X:3 Y:0 R:3 T:2 |  X:0 Y:0 R:0 T:3 |  X:123 Y:148 R:2 T:4 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:1 T:3 |  X:215 Y:151 R:3 T:0 |  X:0 Y:0 R:1 T:2 |  X:1 Y:0 R:0 T:2 |  X:90 Y:102 R:3 T:4 |  X:0 Y:0 R:1 T:3 |  X:250 Y:53 R:1 T:4 |  X:0 Y:0 R:2 T:1 |  X:0 Y:0 R:3 T:3 |  X:0 Y:0 R:3 T:1 |  X:38 Y:51 R:1 T:1 |  X:61 Y:7 R:1 T:0 |  X:6 Y:0 R:0 T:3 |  X:234 Y:245 R:1 T:4 |  X:191 Y:3 R:1 T:4 |  X:7 Y:0 R:1 T:2 |  X:1 Y:0 R:0 T:1 |  X:228 Y:2 R:3 T:1 |  X:186 Y:136 R:0 T:4 |  X:7 Y:0 R:2 T:1 |  X:5 Y:0 R:2 T:1 |  X:2 Y:0 R:0 T:2 |  X:153 Y:218 R:2 T:4 |  X:162 Y:5 R:0 T:2 |
# -------------------------------- 76 GEN ---------------------------------------
# Average pop quality: 286.2995
# HIGHEST QUALITY IN GENERATION: 350
# Backpack: X:7 Y:0 R:0 T:0 |  X:5 Y:0 R:2 T:0 |  X:6 Y:0 R:3 T:2 |  X:4 Y:0 R:2 T:3 |  X:24 Y:31 R:2 T:4 |  X:0 Y:0 R:2 T:3 |  X:0 Y:0 R:3 T:3 |  X:199 Y:181 R:3 T:0 |  X:0 Y:0 R:0 T:2 |  X:3 Y:0 R:1 T:2 |  X:182 Y:116 R:0 T:4 |  X:0 Y:0 R:1 T:3 |  X:12 Y:240 R:2 T:4 |  X:0 Y:0 R:0 T:1 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:0 T:1 |  X:46 Y:13 R:3 T:1 |  X:136 Y:12 R:2 T:0 |  X:4 Y:0 R:0 T:3 |  X:100 Y:196 R:2 T:4 |  X:251 Y:41 R:0 T:4 |  X:0 Y:0 R:1 T:2 |  X:7 Y:0 R:0 T:1 |  X:190 Y:29 R:1 T:1 |  X:83 Y:83 R:0 T:4 |  X:6 Y:0 R:1 T:1 |  X:247 Y:209 R:0 T:1 |  X:1 Y:0 R:3 T:2 |  X:31 Y:138 R:0 T:4 |  X:0 Y:0 R:1 T:2 |
# -------------------------------- 77 GEN ---------------------------------------
# Average pop quality: 289.4415
# HIGHEST QUALITY IN GENERATION: 355
# Backpack: X:0 Y:0 R:2 T:0 |  X:192 Y:231 R:1 T:0 |  X:0 Y:0 R:2 T:2 |  X:0 Y:0 R:0 T:3 |  X:171 Y:220 R:1 T:4 |  X:0 Y:0 R:1 T:3 |  X:1 Y:0 R:2 T:3 |  X:181 Y:208 R:1 T:0 |  X:4 Y:0 R:2 T:2 |  X:3 Y:0 R:1 T:2 |  X:27 Y:166 R:0 T:4 |  X:0 Y:0 R:3 T:3 |  X:74 Y:220 R:3 T:4 |  X:0 Y:0 R:1 T:1 |  X:0 Y:0 R:0 T:3 |  X:0 Y:0 R:3 T:1 |  X:27 Y:186 R:3 T:1 |  X:10 Y:95 R:1 T:0 |  X:4 Y:0 R:3 T:3 |  X:194 Y:8 R:3 T:4 |  X:153 Y:0 R:2 T:4 |  X:0 Y:0 R:3 T:2 |  X:3 Y:0 R:1 T:1 |  X:47 Y:6 R:0 T:1 |  X:177 Y:117 R:3 T:4 |  X:4 Y:0 R:2 T:1 |  X:3 Y:0 R:1 T:1 |  X:0 Y:0 R:0 T:2 |  X:14 Y:0 R:0 T:4 |  X:0 Y:0 R:0 T:2 |
# -------------------------------- 78 GEN ---------------------------------------
# Average pop quality: 293.265
# HIGHEST QUALITY IN GENERATION: 365
# Backpack: X:3 Y:0 R:3 T:0 |  X:2 Y:0 R:3 T:0 |  X:0 Y:0 R:3 T:2 |  X:0 Y:0 R:0 T:3 |  X:62 Y:236 R:0 T:4 |  X:6 Y:0 R:3 T:3 |  X:0 Y:0 R:1 T:3 |  X:68 Y:0 R:2 T:0 |  X:0 Y:0 R:0 T:2 |  X:1 Y:0 R:2 T:2 |  X:84 Y:187 R:0 T:4 |  X:0 Y:0 R:0 T:3 |  X:163 Y:1 R:1 T:4 |  X:0 Y:0 R:1 T:1 |  X:1 Y:0 R:3 T:3 |  X:0 Y:0 R:0 T:1 |  X:27 Y:186 R:3 T:1 |  X:10 Y:95 R:1 T:0 |  X:4 Y:0 R:3 T:3 |  X:194 Y:8 R:3 T:4 |  X:153 Y:0 R:2 T:4 |  X:0 Y:0 R:3 T:2 |  X:3 Y:0 R:1 T:1 |  X:39 Y:6 R:0 T:1 |  X:177 Y:119 R:3 T:4 |  X:4 Y:0 R:2 T:1 |  X:3 Y:0 R:1 T:1 |  X:0 Y:0 R:0 T:2 |  X:11 Y:0 R:0 T:4 |  X:0 Y:0 R:0 T:2 |
# -------------------------------- 79 GEN ---------------------------------------
# Average pop quality: 295.6395
# HIGHEST QUALITY IN GENERATION: 360
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 30
#      26     Algo.CreateAndAddPhenotype(blocksFor1stBackpack)
#      29 for i in range(1, 100):
# ---> 30     Algo.Iterate()
#      31     print(f'-------------------------------- {i+1} GEN ---------------------------------------')
#      33 Algo.ListCurrentPhenotypes()
#
# Cell In[5], line 193, in Algorithm.Iterate(self)
#     191 self.PreviousGen = self.Phenotypes
#     192 #self.Imigration(0.1)
# --> 193 parentPair = self.PairParentsUp(0.20)
#     195 print('Backpack:', end="")
#     196 for b in self.Phenotypes[self.BestSpecimenID]:
#
# Cell In[5], line 75, in Algorithm.PairParentsUp(self, biasParameter, incestSwitch)
#      72 par1Id = random.randint(0, len(self.Phenotypes)-1)
#      73 par2Id = random.randint(0, len(self.Phenotypes)-1)
# ---> 75 par1Quality = self.QualityFunction(self.Phenotypes[par1Id])
#      76 par2Quality = self.QualityFunction(self.Phenotypes[par2Id])
#      78 if(par1Quality >= par2Quality):
#
# Cell In[5], line 110, in Algorithm.QualityFunction(self, backpack)
#     108 #here we need to check legality of a backpack
#     109 for blockTuple in backpack:
# --> 110     if(self.isInsideBackpack(blockTuple)):
#     111         quality += self.typeValueArray[blockTuple[1]]
#     112     #generally, the alogorith will decide if the block is inside by moving coordinates
#     113     #so no need for special bit for "isInsideBackpack"
#
# Cell In[5], line 117, in Algorithm.isInsideBackpack(self, blockTuple)
#     114     return quality
#     116 #no sensical implementation for testing sake, HARDCODED FOR 2 DIM
# --> 117 def isInsideBackpack(self, blockTuple):
#     118     block = self.__translateBinaryToBlock(blockTuple[0])
#     120     type = blockTuple[1]
#
# KeyboardInterrupt:
